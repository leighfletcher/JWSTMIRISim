# %% [markdown]
# **MIRI/MRS Pipeline Script applied to Uranus Cubes**
#
# Based heavily on notebooks by Patrick Kavanagh (DIAS, Ireland): https://github.com/PaddyKavanagh/build7.2.1_notebooks/blob/master/MRS_pipeline.ipynb
#
# * Installed from instructions on https://github.com/spacetelescope/jwst
# * `conda create -n jwst_test python`
# * `conda activate jwst_test`
# * `pip install jwst`
# * <code>export CRDS_PATH=$HOME/crds_cache</code>
# * <code>export CRDS_SERVER_URL=https://jwst-crds.stsci.edu</code>
# * Execution of the level 2A, 2B, and 3 pipelines for MRS data in Python.
# * `source activate jwst_test` before opening this notebook.
#
# The steps applied are:
# * Ramps to slopes pipeline (Detector1Pipeline)
# * CALSPEC2 steps and spectral extraction from each dither (Spec2Pipeline)
# * Combination of dithers and spectral extraction (Spec3Pipeline)
# * Manual conversion of extracted spectra to Jy

# %%
# Imports

import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# set the CRDS_CONTEXT for the correct build (here 0.18.1)
os.environ["CRDS_CONTEXT"] = "jwst_0664.pmap"

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots
# Out:
# 2021-01-08 20:49:00,814 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Set input, output location and source type**
#
# Since we know the simulation is of a point source, we can set the source type metadata to 'POINT' at this stage as that information is used later in spectral extraction. Otherwise, the pipeline will set the default source type for MRS which is 'EXTENDED'

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'testdir'

input_dir = 'testdir'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the source type as 'POINT'
for f in input_files:
    with datamodels.MIRIRampModel(f) as dm:
        dm.meta.target.source_type = 'EXTENDED'
        dm.save(os.path.join(input_dir, dm.meta.filename))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)
# Out:
# /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# Print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:

    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band))
        print("\n\n")

    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t Detector\t nInts\t nGrps\t rdPatt\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %d\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,channel,band))
        print("\n\n")

    # fits extension table
    hdulist.info()
# Out:
# /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ID	 Detector	 nInts	 nGrps	 rdPatt	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFULONG	 10	 10	 FAST	 34	 MEDIUM
#
#
#
# Filename: testdir/det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     110   ()
#   1  SCI           1 ImageHDU        49   (1032, 1024, 10, 10)   float32
#   2  PIXELDQ       1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   3  GROUPDQ       1 ImageHDU        11   (1032, 1024, 10, 10)   uint8
#   4  ERR           1 ImageHDU        11   (1032, 1024, 10, 10)   float32
#   5  REFOUT        1 ImageHDU        11   (258, 1024, 10, 10)   float32
#   6  ASDF          1 BinTableHDU     11   1R x 1C   [528390941B]

# %% [markdown]
# Show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs = axs.ravel()

i = 0
for f in input_files:
    # open the input image as a jwst data model
    with datamodels.MIRIRampModel(f) as in_dm:

        dith_num = i+1
        axs[i].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[i].annotate('Dither %d' % dith_num, xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[i].set_facecolor('black')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# ## Level 2A pipeline (ramps-to-slopes)
# Import the level 2A pipeline class and print description.
# The output level 2A files will be saved in the output_dir as '*_rate.fits'

# %%
#LEVEL 2A PIPELINE

from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)

for f in input_files:
    Detector1Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir,
                           steps={'ipc': {'skip': True},
                                  'dark_current': {'skip': True},
                                  'refpix': {'skip': True}})
# Out:
# /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 2021-01-08 20:18:26,863 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.
# 2021-01-08 20:18:28,985 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,849 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,864 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,882 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,900 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,918 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,940 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,959 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,975 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:30,993 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,009 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,025 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,041 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,055 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,069 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,084 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:31,108 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2021-01-08 20:18:31,109 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2021-01-08 20:18:31,110 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2021-01-08 20:18:31,111 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2021-01-08 20:18:31,116 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2021-01-08 20:18:31,118 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2021-01-08 20:18:31,119 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2021-01-08 20:18:31,120 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2021-01-08 20:18:31,122 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2021-01-08 20:18:31,124 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2021-01-08 20:18:31,126 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2021-01-08 20:18:31,127 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2021-01-08 20:18:31,129 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2021-01-08 20:18:31,130 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2021-01-08 20:18:31,132 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2021-01-08 20:18:31,134 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2021-01-08 20:18:31,135 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2021-01-08 20:18:31,373 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('testdir/det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits',).
# 2021-01-08 20:18:31,385 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'in ...
# 2021-01-08 20:18:31,396 - stpipe.Detector1Pipeline - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-01-08 20:18:32,574 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits' reftypes = ['gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2021-01-08 20:18:32,581 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_gain_0006.fits'.
# 2021-01-08 20:18:32,585 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_linearity_0027.fits'.
# 2021-01-08 20:18:32,586 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_mask_0021.fits'.
# 2021-01-08 20:18:32,587 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2021-01-08 20:18:32,588 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_readnoise_0075.fits'.
# 2021-01-08 20:18:32,589 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_reset_0034.fits'.
# 2021-01-08 20:18:32,590 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_rscd_0011.fits'.
# 2021-01-08 20:18:32,590 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_saturation_0021.fits'.
# 2021-01-08 20:18:32,591 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2021-01-08 20:18:32,592 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2021-01-08 20:18:32,592 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2021-01-08 20:18:32,594 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2021-01-08 20:18:34,073 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:34,074 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:34,087 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES=1 is a power of 2; correction not needed
# 2021-01-08 20:18:34,088 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2021-01-08 20:18:34,089 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2021-01-08 20:18:34,159 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:34,162 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:34,177 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_mask_0021.fits
# 2021-01-08 20:18:35,528 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2021-01-08 20:18:35,616 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:35,618 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:35,650 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_saturation_0021.fits
# 2021-01-08 20:18:38,240 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 saturated pixels
# 2021-01-08 20:18:38,287 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2021-01-08 20:18:38,290 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2021-01-08 20:18:38,447 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:38,448 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:38,449 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2021-01-08 20:18:38,450 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2021-01-08 20:18:38,513 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:38,514 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:39,181 - stpipe.Detector1Pipeline.firstframe - INFO - Step firstframe done
# 2021-01-08 20:18:39,334 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:39,335 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:39,880 - stpipe.Detector1Pipeline.lastframe - INFO - Step lastframe done
# 2021-01-08 20:18:40,029 - stpipe.Detector1Pipeline.reset - INFO - Step reset running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:40,030 - stpipe.Detector1Pipeline.reset - INFO - Step reset parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:40,045 - stpipe.Detector1Pipeline.reset - INFO - Using RESET reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_reset_0034.fits
# 2021-01-08 20:18:40,909 - stpipe.Detector1Pipeline.reset - INFO - Step reset done
# 2021-01-08 20:18:41,069 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:41,070 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:18:41,086 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_linearity_0027.fits
# 2021-01-08 20:18:42,320 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2021-01-08 20:18:42,496 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:42,498 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir', 'type': 'baseline'}
# 2021-01-08 20:18:42,513 - stpipe.Detector1Pipeline.rscd - INFO - Using RSCD reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_rscd_0011.fits
# 2021-01-08 20:18:43,115 - stpipe.Detector1Pipeline.rscd - INFO - Step rscd done
# 2021-01-08 20:18:43,273 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:43,275 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir', 'dark_output': None}
# 2021-01-08 20:18:43,276 - stpipe.Detector1Pipeline.dark_current - INFO - Step skipped.
# 2021-01-08 20:18:43,277 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2021-01-08 20:18:43,343 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:43,344 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}
# 2021-01-08 20:18:43,345 - stpipe.Detector1Pipeline.refpix - INFO - Step skipped.
# 2021-01-08 20:18:43,346 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2021-01-08 20:18:43,412 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:43,413 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir', 'rejection_threshold': 4.0, 'maximum_cores': 'none', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 200.0, 'min_jump_to_flag_neighbors': 10.0}
# 2021-01-08 20:18:43,426 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2021-01-08 20:18:43,430 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2021-01-08 20:18:43,455 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_readnoise_0075.fits
# 2021-01-08 20:18:43,481 - stpipe.Detector1Pipeline.jump - INFO - Found 8 possible cores to use for jump detection
# 2021-01-08 20:18:44,214 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2021-01-08 20:18:48,687 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2021-01-08 20:18:49,085 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 10923 pixels with at least one CR
# 2021-01-08 20:18:49,515 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2021-01-08 20:18:49,836 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14909 pixels with at least one CR
# 2021-01-08 20:18:50,411 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 3:
# 2021-01-08 20:18:50,656 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14888 pixels with at least one CR
# 2021-01-08 20:18:51,190 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 4:
# 2021-01-08 20:18:51,456 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 15012 pixels with at least one CR
# 2021-01-08 20:18:52,011 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 5:
# 2021-01-08 20:18:52,284 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14708 pixels with at least one CR
# 2021-01-08 20:18:52,828 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 6:
# 2021-01-08 20:18:53,092 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14631 pixels with at least one CR
# 2021-01-08 20:18:53,656 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 7:
# 2021-01-08 20:18:53,897 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14757 pixels with at least one CR
# 2021-01-08 20:18:54,458 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 8:
# 2021-01-08 20:18:54,716 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14479 pixels with at least one CR
# 2021-01-08 20:18:55,270 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 9:
# 2021-01-08 20:18:55,525 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14907 pixels with at least one CR
# 2021-01-08 20:18:56,094 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 10:
# 2021-01-08 20:18:56,354 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 14605 pixels with at least one CR
# 2021-01-08 20:18:56,941 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 12.7271 sec
# 2021-01-08 20:18:56,958 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 13.531676
# 2021-01-08 20:18:56,960 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2021-01-08 20:18:57,117 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(10, 10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:18:57,119 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# 2021-01-08 20:18:57,140 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_readnoise_0075.fits
# 2021-01-08 20:18:57,159 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_gain_0006.fits
# 2021-01-08 20:18:57,173 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2021-01-08 20:18:57,173 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2021-01-08 20:18:57,431 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2021-01-08 20:18:57,435 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2021-01-08 20:21:23,358 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 10
# 2021-01-08 20:21:23,358 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 10
# 2021-01-08 20:21:23,491 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2021-01-08 20:21:23,634 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:21:23,635 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:21:23,658 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2021-01-08 20:21:23,659 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2021-01-08 20:21:23,660 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2021-01-08 20:21:23,724 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(10, 1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits>,).
# 2021-01-08 20:21:23,726 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': 'testdir'}
# 2021-01-08 20:21:23,749 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2021-01-08 20:21:23,750 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2021-01-08 20:21:23,753 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2021-01-08 20:21:24,394 - stpipe.Detector1Pipeline - INFO - Saved model in testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_rateints.fits
# 2021-01-08 20:21:24,395 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2021-01-08 20:21:24,510 - stpipe.Detector1Pipeline - INFO - Saved model in testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits
# 2021-01-08 20:21:24,510 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Quick check of the pipeline steps applied in the output. We'll look at the first dither:
level2A_files = glob.glob(os.path.join(output_dir,'*_rate.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('dq_init: %s' % dm.meta.cal_step.dq_init)
    print('saturation: %s' % dm.meta.cal_step.saturation)
    print('ipc: %s' % dm.meta.cal_step.ipc)
    print('linearity: %s' % dm.meta.cal_step.linearity)
    print('rscd: %s' % dm.meta.cal_step.rscd)
    print('firstframe: %s' % dm.meta.cal_step.firstframe)
    print('lastframe: %s' % dm.meta.cal_step.lastframe)
    print('dark_current: %s' % dm.meta.cal_step.dark_sub)
    print('refpix: %s' % dm.meta.cal_step.refpix)
    print('jump: %s' % dm.meta.cal_step.jump)
    print('ramp_fit: %s' % dm.meta.cal_step.ramp_fit)
# Out:
# 2021-01-08 20:21:35,325 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# ipc: None
# linearity: COMPLETE
# rscd: COMPLETE
# firstframe: COMPLETE
# lastframe: COMPLETE
# dark_current: None
# refpix: None
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ## Level 2B pipeline
# import the level 2B pipeline class and print description.
# We pass the level 2A files. The output level 2B files will be saved in the output_dir as '*_cal.fits'.
# Note that since MIRISim does not add straylight, we can skip the straylight correction step.
#
# The level 2B pipeline for the MRS produces three files for each input:
# * _cal.fits - the calibrated level 2B file from each dither
# * _s3d.fits - the cube from each dither
# * _x1d.fits - the 1d spectrum from each dither

# %%
from jwst.pipeline import Spec2Pipeline
print(Spec2Pipeline.__doc__)

for f in level2A_files:
    Spec2Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir, 
                       steps={'straylight':{'skip':True}})
# Out:
# 2021-01-08 20:21:45,725 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, barshadow,  photom,
#     resample_spec, cube_build, and extract_1d.
# 2021-01-08 20:21:46,092 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2021-01-08 20:21:46,094 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2021-01-08 20:21:46,097 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2021-01-08 20:21:46,098 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2021-01-08 20:21:46,099 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2021-01-08 20:21:46,101 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2021-01-08 20:21:46,105 - stpipe.Spec2Pipeline.master_background - INFO - MasterBackgroundNrsSlitsStep instance created.
# 2021-01-08 20:21:46,107 - stpipe.Spec2Pipeline.master_background.flat_field - INFO - FlatFieldStep instance created.
# 2021-01-08 20:21:46,109 - stpipe.Spec2Pipeline.master_background.pathloss - INFO - PathLossStep instance created.
# 2021-01-08 20:21:46,112 - stpipe.Spec2Pipeline.master_background.barshadow - INFO - BarShadowStep instance created.
# 2021-01-08 20:21:46,114 - stpipe.Spec2Pipeline.master_background.photom - INFO - PhotomStep instance created.
# 2021-01-08 20:21:46,116 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2021-01-08 20:21:46,118 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2021-01-08 20:21:46,120 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2021-01-08 20:21:46,123 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2021-01-08 20:21:46,125 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2021-01-08 20:21:46,128 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2021-01-08 20:21:46,130 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2021-01-08 20:21:46,131 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2021-01-08 20:21:46,134 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2021-01-08 20:21:46,137 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2021-01-08 20:21:46,140 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2021-01-08 20:21:46,599 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits',).
# 2021-01-08 20:21:46,618 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'grism_objects': None, 'mmag_extract': 99.0}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}}}, 'wavecorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file':  ...
# 2021-01-08 20:21:46,675 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits' reftypes = ['apcorr', 'area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'drizpars', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'resol', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2021-01-08 20:21:46,681 - stpipe.Spec2Pipeline - INFO - Prefetch for APCORR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf'.
# 2021-01-08 20:21:46,682 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2021-01-08 20:21:46,683 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2021-01-08 20:21:46,683 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2021-01-08 20:21:46,684 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2021-01-08 20:21:46,684 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits'.
# 2021-01-08 20:21:46,685 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2021-01-08 20:21:46,686 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2021-01-08 20:21:46,686 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_distortion_0033.asdf'.
# 2021-01-08 20:21:46,687 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2021-01-08 20:21:46,687 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf'.
# 2021-01-08 20:21:46,688 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2021-01-08 20:21:46,688 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2021-01-08 20:21:46,689 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_flat_0539.fits'.
# 2021-01-08 20:21:46,689 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2021-01-08 20:21:46,690 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2021-01-08 20:21:46,690 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_fringe_0044.fits'.
# 2021-01-08 20:21:46,691 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2021-01-08 20:21:46,691 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2021-01-08 20:21:46,692 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2021-01-08 20:21:46,693 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2021-01-08 20:21:46,693 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2021-01-08 20:21:46,694 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2021-01-08 20:21:46,695 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is 'N/A'.
# 2021-01-08 20:21:46,696 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_photom_0049.fits'.
# 2021-01-08 20:21:46,697 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_regions_0030.asdf'.
# 2021-01-08 20:21:46,697 - stpipe.Spec2Pipeline - INFO - Prefetch for RESOL reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2021-01-08 20:21:46,698 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2021-01-08 20:21:46,699 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_specwcs_0023.asdf'.
# 2021-01-08 20:21:46,700 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2021-01-08 20:21:46,700 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0004.asdf'.
# 2021-01-08 20:21:46,701 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2021-01-08 20:21:46,701 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2021-01-08 20:21:46,702 - stpipe.Spec2Pipeline - INFO - Processing product testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1
# 2021-01-08 20:21:46,703 - stpipe.Spec2Pipeline - INFO - Working on input testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits ...
# 2021-01-08 20:21:46,814 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:46,815 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2021-01-08 20:21:51,087 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_mrs pipeline with references {'distortion': '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_distortion_0033.asdf', 'filteroffset': None, 'specwcs': '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_specwcs_0023.asdf', 'regions': '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_regions_0030.asdf', 'wavelengthrange': '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_wavelengthrange_0004.asdf', 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2021-01-08 20:21:52,129 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  0.000000004 -0.001210064 359.999999999 -0.001210064 359.999999999 0.001047898 0.000000004 0.001047898
# 2021-01-08 20:21:52,129 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2021-01-08 20:21:52,133 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2021-01-08 20:21:52,224 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>, []).
# 2021-01-08 20:21:52,226 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'sigma': 3.0, 'maxiters': None}
# 2021-01-08 20:21:52,227 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2021-01-08 20:21:52,229 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2021-01-08 20:21:52,321 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>, []).
# 2021-01-08 20:21:52,323 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined'}
# 2021-01-08 20:21:52,323 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2021-01-08 20:21:52,324 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2021-01-08 20:21:52,417 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:52,419 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined'}
# 2021-01-08 20:21:52,419 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2021-01-08 20:21:52,420 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2021-01-08 20:21:52,512 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:52,514 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined'}
# 2021-01-08 20:21:52,526 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2021-01-08 20:21:52,527 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = None
# 2021-01-08 20:21:52,528 - stpipe.Spec2Pipeline.srctype - WARNING - SRCTYAPT keyword not found in input; using SRCTYPE instead
# 2021-01-08 20:21:52,529 - stpipe.Spec2Pipeline.srctype - INFO - Using input source type = EXTENDED
# 2021-01-08 20:21:52,531 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2021-01-08 20:21:52,612 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:52,614 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2021-01-08 20:21:52,706 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-08 20:21:53,630 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2021-01-08 20:21:53,738 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:53,740 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'method': 'ModShepard', 'roi': 50, 'power': 1.0}
# 2021-01-08 20:21:53,740 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2021-01-08 20:21:53,742 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2021-01-08 20:21:53,846 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:53,848 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined'}
# 2021-01-08 20:21:53,862 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_fringe_0044.fits
# 2021-01-08 20:21:53,920 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-08 20:21:53,921 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-08 20:21:53,922 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-08 20:21:54,846 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2021-01-08 20:21:54,848 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2021-01-08 20:21:55,000 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:55,002 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'inverse': False, 'source_type': None}
# 2021-01-08 20:21:55,002 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2021-01-08 20:21:55,003 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2021-01-08 20:21:55,103 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:55,105 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'inverse': False, 'source_type': None}
# 2021-01-08 20:21:55,106 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2021-01-08 20:21:55,107 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2021-01-08 20:21:55,203 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-01-08 20:21:55,205 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'inverse': False, 'source_type': None}
# 2021-01-08 20:21:55,222 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_photom_0049.fits
# 2021-01-08 20:21:55,223 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2021-01-08 20:21:56,128 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2021-01-08 20:21:56,129 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFULONG
# 2021-01-08 20:21:56,129 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2021-01-08 20:21:56,130 - stpipe.Spec2Pipeline.photom - INFO -  band: MEDIUM
# 2021-01-08 20:21:56,212 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-01-08 20:21:56,229 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2021-01-08 20:21:56,396 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits>,).
# 2021-01-08 20:21:56,398 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': 'testdir_pipelined', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}
# 2021-01-08 20:21:56,399 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2021-01-08 20:21:56,400 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2021-01-08 20:21:56,401 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2021-01-08 20:21:56,402 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: emsm
# 2021-01-08 20:21:56,403 - stpipe.Spec2Pipeline.cube_build - INFO - Power weighting distance: 2.0
# 2021-01-08 20:21:56,426 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes cover the MIRI Channels: ['3', '4']
# 2021-01-08 20:21:56,427 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['medium', 'medium']
# 2021-01-08 20:21:56,428 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits
# 2021-01-08 20:21:57,517 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2021-01-08 20:21:57,518 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2021-01-08 20:21:58,065 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2021-01-08 20:21:58,066 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-01-08 20:21:58,066 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    47  24.00   0.00016387   0.20000000  -4.70000007   4.70000007
# 2021-01-08 20:21:58,067 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    45  23.00  -0.00008108   0.20000000  -4.50000007   4.50000007
# 2021-01-08 20:21:58,067 - stpipe.Spec2Pipeline.cube_build - INFO - Non-linear wavelength dimension; CDELT3 variable
# 2021-01-08 20:21:58,068 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL     Min & Max (microns)
# 2021-01-08 20:21:58,068 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  2245   1.00  13.36956596  13.36956596  24.21399689
# 2021-01-08 20:21:58,069 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 3, medium
# 2021-01-08 20:21:58,069 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 4, medium
# 2021-01-08 20:21:58,070 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_s3d.fits
# 2021-01-08 20:21:58,389 - stpipe.Spec2Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 6757 with wavelength below 13.36698055267334
# 2021-01-08 20:25:40,641 - stpipe.Spec2Pipeline.cube_build - INFO - Time to match file to ifucube = 124.6 s
# 2021-01-08 20:25:40,932 - stpipe.Spec2Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 5350 with wavelength above 24.22562026977539
# 2021-01-08 20:29:00,896 - stpipe.Spec2Pipeline.cube_build - INFO - Time to match file to ifucube = 125.3 s
# 2021-01-08 20:29:01,035 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2021-01-08 20:29:01,035 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2021-01-08 20:29:01,039 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux = 0.1 s
# 2021-01-08 20:29:01,292 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  0.001441650 -0.001303305 0.001441650 0.001141139 359.998886094 0.001141139 359.998886094 -0.001303305
# 2021-01-08 20:29:01,320 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2021-01-08 20:29:01,621 - stpipe.Spec2Pipeline - INFO - Saved model in testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_s3d.fits
# 2021-01-08 20:29:01,709 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2021-01-08 20:29:01,711 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': 'testdir_pipelined', 'smoothing_length': None, 'bkg_fit': 'poly', 'bkg_order': None, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'apply_apcorr': True}
# 2021-01-08 20:29:01,717 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-01-08 20:29:01,721 - stpipe.Spec2Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-01-08 20:29:04,788 - stpipe.Spec2Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-01-08 20:29:04,789 - stpipe.Spec2Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-01-08 20:29:04,789 - stpipe.Spec2Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-01-08 20:29:08,794 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_x1d.fits
# 2021-01-08 20:29:08,795 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2021-01-08 20:29:08,807 - stpipe.Spec2Pipeline - INFO - Finished processing product testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1
# 2021-01-08 20:29:08,808 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2021-01-08 20:29:09,712 - stpipe.Spec2Pipeline - INFO - Saved model in testdir_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits
# 2021-01-08 20:29:09,713 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %%
# check of output

# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))
cube_files = glob.glob(os.path.join(output_dir,'*_s3d.fits'))

with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('assign_wcs: %s' % dm.meta.cal_step.assign_wcs)
    print('flat_field: %s' % dm.meta.cal_step.flat_field)
    print('srctype: %s' % dm.meta.cal_step.srctype)
    print('straylight: %s' % dm.meta.cal_step.straylight)
    print('fringe: %s' % dm.meta.cal_step.fringe)
    print('photom: %s' % dm.meta.cal_step.photom)
# Out:
# 2021-01-08 20:29:55,932 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Check step information status:
# assign_wcs: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# straylight: None
# fringe: COMPLETE
# photom: COMPLETE

# %% [markdown]
# Look at level 1B and calibrated level 2B image. We'll look at the first dither only.

# %%
# open the input image as a jwst data model
with datamodels.MIRIRampModel(input_files[0]) as in_dm:
    with datamodels.open(level2B_files[0]) as out_dm:
        
        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_facecolor('black')
        axs[1].imshow(out_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=1000)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_facecolor('black')

        plt.tight_layout()
        plt.show()
# Out:
# 2021-01-08 20:32:55,443 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#
# 2021-01-08 20:32:55,448 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# Look at cube file. We'll look at the first dither only

# %%
# open the cube as a jwst data model
with datamodels.open(cube_files[0]) as cube_dm:
    
    # plot--------------------------------------
    # sum some of the the frames in each channel
    # Note the user may have to adjust the scaling
    # parameters
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e5,vmax=1e7))
    axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(np.sum(cube_dm.data[3000:3200], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1,vmax=1e6))
    axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    
    plt.tight_layout()
    plt.show()
# Out:
# 2021-01-08 20:31:55,877 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Level 3 pipeline
# We first create an association file in the output directory containing the list of level 2B files ("_cal.fits") produced by the level 2B pipeline.
#
# Create the level 3 association using the asn_from_list tool

# %%
call(["asn_from_list", "-o", "MRS_asn.json"] + level2B_files + ["--product-name", "dither"])


from jwst.pipeline import Spec3Pipeline
print(Spec3Pipeline.__doc__)

# read the association and run
dms = datamodels.open("MRS_asn.json")
Spec3Pipeline.call(dms, save_results=True, output_dir=output_dir,
                  steps={'cube_build': {'save_results': True, 'output_dir': output_dir},
                         'extract_1d': {'save_results': True, 'output_dir': output_dir},
                         'mrs_imatch': {'skip': True}})
# Out:
# 2021-01-08 20:33:05,187 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Spec3Pipeline: Processes JWST spectroscopic exposures from Level 2b to 3.
#
#     Included steps are:
#     assign moving target wcs (assign_mtwcs)
#     master background subtraction (master_background)
#     MIRI MRS background matching (mrs_imatch)
#     outlier detection (outlier_detection)
#     2-D spectroscopic resampling (resample_spec)
#     3-D spectroscopic resampling (cube_build)
#     1-D spectral extraction (extract_1d)
#     1-D spectral combination (combine_1d)
# 2021-01-08 20:33:18,774 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2021-01-08 20:33:18,776 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2021-01-08 20:33:18,778 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2021-01-08 20:33:18,779 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2021-01-08 20:33:18,781 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2021-01-08 20:33:18,784 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2021-01-08 20:33:18,786 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2021-01-08 20:33:18,788 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2021-01-08 20:33:18,791 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2021-01-08 20:33:19,010 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args (<ModelContainer>,).
# 2021-01-08 20:33:19,020 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '4.0 3.0', 'scale': '0.5 0.4', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'exptime', 'pixel_scale_ratio': 1.0, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': 'poly', 'bkg_order': None, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'apply_apcorr': True}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'exptime_key': 'exposure_time'}}}
# 2021-01-08 20:33:19,023 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits' reftypes = ['apcorr', 'cubepar', 'drizpars', 'extract1d', 'resol']
# 2021-01-08 20:33:19,027 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf'.
# 2021-01-08 20:33:19,028 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits'.
# 2021-01-08 20:33:19,028 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2021-01-08 20:33:19,029 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf'.
# 2021-01-08 20:33:19,030 - stpipe.Spec3Pipeline - INFO - Prefetch for RESOL reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2021-01-08 20:33:19,031 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2021-01-08 20:33:19,216 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch running with args (<ModelContainer>,).
# 2021-01-08 20:33:19,218 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'mrs_imatch', 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}
# 2021-01-08 20:33:19,218 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step skipped.
# 2021-01-08 20:33:19,219 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch done
# 2021-01-08 20:33:19,365 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2021-01-08 20:33:19,368 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '4.0 3.0', 'scale': '0.5 0.4', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2021-01-08 20:33:19,372 - stpipe.Spec3Pipeline.outlier_detection - WARNING - Input only contains 1 exposure
# 2021-01-08 20:33:19,372 - stpipe.Spec3Pipeline.outlier_detection - WARNING - Outlier detection step will be skipped
# 2021-01-08 20:33:19,374 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2021-01-08 20:33:19,517 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2021-01-08 20:33:19,521 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}
# 2021-01-08 20:33:19,522 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2021-01-08 20:33:19,523 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2021-01-08 20:33:19,523 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2021-01-08 20:33:19,524 - stpipe.Spec3Pipeline.cube_build - INFO - Weighting method for point cloud: emsm
# 2021-01-08 20:33:19,525 - stpipe.Spec3Pipeline.cube_build - INFO - Power weighting distance: 2.0
# 2021-01-08 20:33:19,543 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes cover the MIRI Channels: ['3', '4']
# 2021-01-08 20:33:19,544 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['medium', 'medium']
# 2021-01-08 20:33:19,544 - stpipe.Spec3Pipeline.cube_build - INFO - Reading cube parameter file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits
# 2021-01-08 20:33:20,612 - stpipe.Spec3Pipeline.cube_build - INFO - Output Cubes are single channel, single sub-channel IFU Cubes
# 2021-01-08 20:33:20,613 - stpipe.Spec3Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 2
# 2021-01-08 20:33:20,928 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2021-01-08 20:33:20,929 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-01-08 20:33:20,929 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    37  19.00  -0.00001522   0.20000000  -3.70000006   3.70000006
# 2021-01-08 20:33:20,929 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    37  19.00  -0.00000794   0.20000000  -3.70000006   3.70000006
# 2021-01-08 20:33:20,930 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2021-01-08 20:33:20,930 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3   757   1.00  13.37149989   0.00300000  13.36999989  15.64099991
# 2021-01-08 20:33:20,931 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 3, medium
# 2021-01-08 20:33:20,931 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: testdir_pipelined/dither_ch3-medium_s3d.fits
# 2021-01-08 20:33:21,276 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 6977 with wavelength below 13.368499885546044
# 2021-01-08 20:33:21,277 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 11286 with wavelength above 15.642499905312434
# 2021-01-08 20:34:57,147 - stpipe.Spec3Pipeline.cube_build - INFO - Time to match file to ifucube = 63.9 s
# 2021-01-08 20:34:57,188 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2021-01-08 20:34:57,189 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2021-01-08 20:34:57,190 - stpipe.Spec3Pipeline.cube_build - INFO - Time to find Cube Flux = 0.0 s
# 2021-01-08 20:34:57,513 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2021-01-08 20:34:57,514 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-01-08 20:34:57,514 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    29  15.00   0.00016387   0.34999999  -5.07499991   5.07499991
# 2021-01-08 20:34:57,515 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    27  14.00  -0.00008108   0.34999999  -4.72499992   4.72499992
# 2021-01-08 20:34:57,516 - stpipe.Spec3Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2021-01-08 20:34:57,516 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3   632   1.00  20.42300008   0.00600000  20.42000008  24.21200011
# 2021-01-08 20:34:57,517 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 4, medium
# 2021-01-08 20:34:57,518 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name: testdir_pipelined/dither_ch4-medium_s3d.fits
# 2021-01-08 20:34:57,816 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 4506 with wavelength below 20.41700007626787
# 2021-01-08 20:34:57,816 - stpipe.Spec3Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 6252 with wavelength above 24.21500010928139
# 2021-01-08 20:36:01,210 - stpipe.Spec3Pipeline.cube_build - INFO - Time to match file to ifucube = 48.4 s
# 2021-01-08 20:36:01,228 - stpipe.Spec3Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2021-01-08 20:36:01,228 - stpipe.Spec3Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2021-01-08 20:36:01,230 - stpipe.Spec3Pipeline.cube_build - INFO - Time to find Cube Flux = 0.0 s
# 2021-01-08 20:36:01,292 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  0.000984777 -0.001007937 0.000984777 0.000992063 359.998984777 0.000992063 359.998984777 -0.001007937
# 2021-01-08 20:36:01,295 - stpipe.Spec3Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  0.001524983 -0.001344972 0.001524983 0.001182806 359.998802761 0.001182806 359.998802761 -0.001344972
# 2021-01-08 20:36:01,433 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in testdir_pipelined/dither_ch3-medium_s3d.fits
# 2021-01-08 20:36:01,544 - stpipe.Spec3Pipeline.cube_build - INFO - Saved model in testdir_pipelined/dither_ch4-medium_s3d.fits
# 2021-01-08 20:36:01,545 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2021-01-08 20:36:01,676 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2021-01-08 20:36:01,677 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'testdir_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': False, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': 'poly', 'bkg_order': None, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'apply_apcorr': True}
# 2021-01-08 20:36:01,684 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-01-08 20:36:01,687 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-01-08 20:36:04,756 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-01-08 20:36:04,757 - stpipe.Spec3Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-01-08 20:36:04,758 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-01-08 20:36:06,001 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-01-08 20:36:06,004 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-01-08 20:36:08,999 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-01-08 20:36:09,000 - stpipe.Spec3Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-01-08 20:36:09,000 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-01-08 20:36:09,970 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in testdir_pipelined/dither_ch3-medium_x1d.fits
# 2021-01-08 20:36:10,050 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in testdir_pipelined/dither_ch4-medium_x1d.fits
# 2021-01-08 20:36:10,050 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2021-01-08 20:36:10,051 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2021-01-08 20:36:10,051 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
cube_files = sorted(glob.glob(os.path.join(output_dir, 'dither*s3d.fits')))
ch1_cdm = datamodels.open(cube_files[0])
ch2_cdm = datamodels.open(cube_files[1])

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(ch1_cdm.data[100:-100], axis=0), cmap='inferno', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1e7))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(ch2_cdm.data[100:-100], axis=0), cmap='inferno', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1e8))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()
# Out:
# 2021-01-08 20:44:52,752 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
spec_files = sorted(glob.glob(os.path.join(output_dir, 'dither*1d.fits')))
ch1_sdm = datamodels.open(spec_files[0])
ch2_sdm = datamodels.open(spec_files[1])

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# plot the spectrum in the channel 2 wavelength range
spaxel_area = ch1_cdm.meta.wcsinfo.cdelt1 * ch1_cdm.meta.wcsinfo.cdelt2 * 3600**2
axs[0].plot(ch1_sdm.spec[0].spec_table['WAVELENGTH'], ch1_sdm.spec[0].spec_table['FLUX'] * spaxel_area, c='orange', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[0].set_ylabel(r'Flux (mJy)')
axs[0].set_xlabel(r'Wavelength ($\mu$m)')
#axs[0].set_xlim(4.9,30)
#axs[0].set_ylim(10,200)

spaxel_area = ch2_cdm.meta.wcsinfo.cdelt1 * ch2_cdm.meta.wcsinfo.cdelt2 * 3600**2
axs[1].plot(ch2_sdm.spec[0].spec_table['WAVELENGTH'], ch2_sdm.spec[0].spec_table['FLUX']  * spaxel_area, c='g', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[1].set_xlabel(r'Wavelength ($\mu$m)')
#axs[1].set_xlim(7.5,8.7)

axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].grid()
axs[1].grid()

plt.tight_layout()
plt.show()
# Out:
# 2021-01-08 20:52:00,992 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
