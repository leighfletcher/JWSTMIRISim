# %% [markdown]
# ## Notebook to Simulate MIRI Observations based on NEMESIS Outputs
#
# When launching the notebook, make sure in the right Anaconda environment. i.e. type
#
# <code> source activate mirisim </code>
#
# in the terminal before starting the notebook.  This is based on contributions from A. Glasse, N. Rowe-Gurney, and the MIRISim walkthrough.
#
# Mirisim can be run via notebooks or directly as a callable python package.
#
# L.N. Fletcher (2021)
#
# ### Open Questions:
# * Am I correctly mapping the NEMESIS cubes to detector, disperser, MRS sub-band?
# * I am providing only a single MRS sub-band to the simulator, and yet both halves of the detector frame seem to have contents (e.g., CH1/2 for 'SW' detector; CH4/3 for 'LW' detector) - why?
# * Background is not yet included - what are the units?  Are the expected units uJy/arcsec^2?

# %%
# Set up MIRISIM and import useful tools:
from mirisim import MiriSimulation

# import the configuration file parsers so they can be written to file
from mirisim.config_parser import SimConfig, SceneConfig, SimulatorConfig
#from mirisim.skysim import wrap_pysynphot as wS

# import scene component generators
from mirisim.skysim import Background

#other tools to be used
import numpy as np
import glob                 # glob is used to find the output directory
import os                   # for listing directory contents
from astropy.io import fits # for reading FITS file contents

import matplotlib.pyplot as plt    # to display images
from matplotlib import colors,cm
# %matplotlib inline   

import astropy.units as u

# %% [markdown]
# ## 1) Read & Modify the Uranus Scene:
#
# The direct cubes calculated by NEMESIS are subdivided into 12 seperate channels, each with an associated wavelength grid that doesn't appear to be used right now.  In the block that follows, the header of the FITS file is updated to be recognised by the MIRISim code.
#
# #### Mapping Simulation Cube to MRS Parameters
#
# Detector = Specify Dectector (SW = channels 1,2, LW= channels 3,4)
# Channel = channels 1-4 (also called MRS subbands)
# Disperser = Specify disperser to use (SHORT/MEDIUM/LONG, aka A/B/C)
#
# 1. SW 1 SHORT/A
# 1. SW 1 MEDIUM/B
# 1. SW 1 LONG/C
# 1. SW 2 SHORT/A
# 1. SW 2 MEDIUM/B
# 1. SW 2 LONG/C
# 1. LW 3 SHORT/A
# 1. LW 3 MEDIUM/B
# 1. LW 3 LONG/C
# 1. LW 4 SHORT/A
# 1. LW 4 MEDIUM/B
# 1. LW 4 LONG/C

# %%
# Mapping the Cube to the MRS sub-band, disperser, and detector:
ichan=7

if ichan==1:
    ConfigPath = 'MRS_1SHORT'
    disperser = 'SHORT'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan1_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan1_wave.fits"
if ichan==2:
    ConfigPath = 'MRS_1MEDIUM'
    disperser = 'MEDIUM'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan2_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan2_wave.fits"
if ichan==3:
    ConfigPath = 'MRS_1LONG'
    disperser = 'LONG'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan3_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan3_wave.fits"
if ichan==4:
    ConfigPath = 'MRS_2SHORT'
    disperser = 'SHORT'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan4_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan4_wave.fits"
if ichan==5:
    ConfigPath = 'MRS_2MEDIUM'
    disperser = 'MEDIUM'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan5_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan5_wave.fits"
if ichan==6:
    ConfigPath = 'MRS_2LONG'
    disperser = 'LONG'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan6_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan6_wave.fits"
if ichan==7:
    ConfigPath = 'MRS_3SHORT'
    disperser = 'SHORT'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan7_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan7_wave.fits"
if ichan==8:
    ConfigPath = 'MRS_3MEDIUM'
    disperser = 'MEDIUM'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan8_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan8_wave.fits"
if ichan==9:
    ConfigPath = 'MRS_3LONG'
    disperser = 'LONG'
    detector = 'LW'    
    u_raw_fits = "NEMESISCubes/uranusMRS_chan9_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan9_wave.fits"
if ichan==10:
    ConfigPath = 'MRS_4SHORT'
    disperser = 'SHORT'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan10_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan10_wave.fits"
if ichan==11:
    ConfigPath = 'MRS_4MEDIUM'
    disperser = 'MEDIUM'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan11_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan11_wave.fits"
if ichan==12:
    ConfigPath = 'MRS_4LONG'
    disperser = 'LONG'
    detector = 'LW'    
    u_raw_fits = "NEMESISCubes/uranusMRS_chan12_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan12_wave.fits"
    
print("Channel:",ichan)
print("Disperser:",disperser)
print("Optical Path:",ConfigPath)
print("Detector",detector)
    
hdu_list = fits.open(u_raw_fits)
hdu = hdu_list[0]


whdu_list = fits.open(wav_fits)
whdu = whdu_list[0]

wavegrid=whdu.data

vmin=np.min(wavegrid)
vmax=np.max(wavegrid)
nwav=len(wavegrid)
dwave=(vmax-vmin)/nwav

print("Wavelengths:",vmin,vmax,nwav)
print("Dispersion:",dwave)

crpix = (1, 1, 1)
crval = (0., 0., vmin)
dpix = 0.11                 # Pixel size in arcsec
#dwave = 0.00073             # micron (bw / 1300 ~
cdelt = (dpix, dpix, dwave)

hdu.header['CRVAL1'] = crval[0]
hdu.header['CRPIX1'] = crpix[0]
hdu.header['CDELT1'] = cdelt[0]
hdu.header['CUNIT1'] = u.arcsec.to_string()
hdu.header['CTYPE1'] = 'RA---TAN'

hdu.header['CRVAL2'] = crval[1]
hdu.header['CRPIX2'] = crpix[1]
hdu.header['CDELT2'] = cdelt[1]
hdu.header['CUNIT2'] = u.arcsec.to_string()
hdu.header['CTYPE2'] = 'DEC--TAN'

hdu.header['CRVAL3'] = crval[2]
hdu.header['CRPIX3'] = crpix[2]
hdu.header['CDELT3'] = cdelt[2]
hdu.header['CUNIT3'] = u.micron.to_string()
hdu.header['CTYPE3'] = 'WAVE    '

hdu.header['UNITS'] = 'uJy / arcsec2'  #u.microjansky.to_string()

hdu.data = np.multiply(hdu.data, 1.0e6)  # NEMESIS data in Jy/arcsec^2, multiply to get microJy/arcsec^2

run_file_name = 'run_scene.fits'
if os.path.isfile(run_file_name):
    os.remove(run_file_name)
hdu.writeto(run_file_name)

print("Modified FITS file created")
# Out:
# Channel: 7
# Disperser: SHORT
# Optical Path: MRS_3SHORT
# Detector LW
# Wavelengths: 11.44 13.6398 974
# Dispersion: 0.002258522065023622
# Modified FITS file created

# %%
### create a low level background for the scene
bg = Background(level='low', gradient = 5., pa = 15.)  # Gradient=0 == contant background)

# NOTE!  bg is currently unused, and needs to be added to the scene or FITS image (see below).
# Out:
# 2021-01-06 15:41:20,312 - INFO - Initializing Background

# %% [markdown]
# # 2) Initialise the Simulation Parameters
#
# This is where the parameters for the MRS simulation get set. Note that for internal consistency in MIRISim, all settings (including those not used in the MRS simulation here) must be set. Those not being used in this simulation are labelled with <code> NOT USED HERE </code> in the comments of each line
#
# MIRISim then needs a configuration file to run.
# Questions:
# * Should we change ConfigPath for each subband?  Yes, doesn't make sense otherwise.
# * Do we need to change the imager filter when using the MRS?  No, don't think it's used.

# %%
sim_config = SimConfig.makeSim(
    name = 'Uranus.test',           # name given to simulation,
    scene = 'uranus_scene',         # name of scene file to input,
    rel_obsdate = 0.0,              # relative observation date (0 = launch, 1 = end of 5 yrs),
    POP = 'MRS',                    # Component on which to center (Imager or MRS),
    ConfigPath = ConfigPath,      # Configure the Optical path (MRS sub-band)
    Dither = False,                 # Dither  - use false for test case
    StartInd = 1,                   # Start index for dither pattern
    NDither = 2,                    # Number of dither positions (12)
    DitherPat = 'mrs_recommended_dither.dat', # dither pattern to use   - If using REULEAUX need to update,
    disperser = disperser,        # Which disperser to use (SHORT/MEDIUM/LONG)
    detector = detector,            # Specify Channel (SW = channels 1,2, LW= channels 3,4)
    mrs_mode = 'FAST',          # MRS read mode (default is SLOW. ~ 24s)
    mrs_exposures = 2,          # MRS number of exposures
    mrs_integrations = 10,      # MRS number of integrations
    mrs_frames = 10,            # MRS number of groups (for MIRI, # Groups = # Frames)
    ima_exposures = 1,          # IMA number of exposures,
    ima_integrations = 10,      # IMA number of integrations (5)",
    ima_frames = 10,            # IMA number of groups (for MIRI, # Groups = # Frames),
    ima_mode = 'FAST',          # IMA read mode (default is FAST ~ 2.3 s),
    filter = 'F770W',           # IMA Filter to use,
    readDetect = 'FULL'         # Portion of detector to read out,
)

simulator_config = SimulatorConfig.from_default()
scene_config = SceneConfig('uranus_scene.ini')

### Suggestion from Alistair for adding background (doesn't work).
#scene_config = SceneConfig('uranus_scene.ini',background=bg)
# Export the simulation setup to a file.
sim_config.write('MRS_simulation.ini')


print("Simulation configuration complete.")
# Out:
# 2021-01-06 15:41:25,788 - INFO - Using scene configuration: uranus_scene.ini
# MRS_simulation.ini exists, overwrite (y/[n])?y
# Simulation configuration complete.

# %% [markdown]
# # 3) Run the simulation
#
# Now that the scene and the setup of the simulation have been set, we can run the simulation.
#
# the last step is to setup the defaults for internal things like CDPs.
# Outputs to unique directory format: YYYYMMDD_HHMMSS_mirisim

# %%
sim = MiriSimulation(sim_config, scene_config, simulator_config)

print("Running simulation:")
sim.run()
# Out:
# 2021-01-06 15:41:51,743 - INFO - MIRISim version: 2.3.0
# 2021-01-06 15:41:51,744 - INFO - MIRI Simulation started.
# 2021-01-06 15:41:51,745 - INFO - Output will be saved to: 20210106_154151_mirisim
# 2021-01-06 15:41:51,746 - INFO - Storing configs in output directory.
# Running simulation:
# 2021-01-06 15:41:52,235 - INFO - Reading cosmic ray properties from parameter file /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/miri/simulators/scasim/cosmic_ray_properties.py
# 2021-01-06 15:41:52,241 - INFO - Reading detector properties from parameter file /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/miri/simulators/scasim/detector_properties.py
# 2021-01-06 15:41:52,287 - INFO - Storing dither pattern in output directory.
# 2021-01-06 15:41:52,289 - WARNING - Environment variable CDP_DIR is not set. Will look up / store CDP files at ./CDP
# 2021-01-06 15:41:52,290 - INFO - Setting up simulated Observation, with following settings:
# 2021-01-06 15:41:52,291 - INFO - Configuration Path: MRS_3SHORT
# 2021-01-06 15:41:52,291 - INFO - Primary optical path: MRS
# 2021-01-06 15:41:52,292 - INFO - MRS detector: LW
# 2021-01-06 15:41:52,293 - INFO - MRS band: SHORT
# 2021-01-06 15:41:52,293 - INFO - MRS detector readout mode: FAST
# 2021-01-06 15:41:52,294 - INFO - MRS detector # exposures: 2
# 2021-01-06 15:41:52,294 - INFO - MRS detector # integrations: 10
# 2021-01-06 15:41:52,295 - INFO - MRS detector # frames: 10
# 2021-01-06 15:41:52,295 - INFO - Parsing: input fits
# 2021-01-06 15:41:52,297 - INFO - Initializing Skycube
# 2021-01-06 15:41:52,297 - INFO - Loading external scene from FITS run_scene.fits
# 2021-01-06 15:41:52,355 - INFO - Aligning the centre of the fits file with the centre of the scene
# 2021-01-06 15:41:52,356 - INFO - Simulating a single pointing.
# 2021-01-06 15:42:14,471 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFUSHORT_12SHORT_DISTORTION_8B.05.01.fits'
# /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/gwcs/wcs.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   transforms = np.array(self._pipeline[from_ind: to_ind])[:, 1].copy()
# 2021-01-06 15:42:15,840 - INFO - Creating pointing for position 1
# 2021-01-06 15:42:15,841 - INFO - Creating exposure event for position 1
# 2021-01-06 15:42:15,843 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:42:16,510 - INFO - Observation simulation started.
# 2021-01-06 15:42:16,511 - INFO - Simulating ExposureEvent for pointing 1
# 2021-01-06 15:42:16,512 - INFO - Simulating MRS exposures for pointing 1
# 2021-01-06 15:42:16,512 - INFO - Creating skycubes for MRS exposures for pointing 1
# 2021-01-06 15:42:16,514 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:42:16,918 - INFO - Downsampling spectral columns of 3721 pixels. This may take long.
# 2021-01-06 15:42:19,914 - INFO - 3D downsampling took 3.0 seconds
# 2021-01-06 15:42:19,915 - INFO - Final helper interpolation...
# 2021-01-06 15:42:20,006 - INFO - All done
# 2021-01-06 15:42:20,036 - INFO - Reading 'PSF' model from './CDP/MIRI_FM_MIRIFULONG_3SHORT_PSF_07.02.00.fits'
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.
# 2021-01-06 15:42:36,431 - INFO - Wrote skycube: 20210106_154151_mirisim/skycubes/skycube_seq1_3SHORT.fits
# 2021-01-06 15:42:36,433 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:42:36,808 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:42:37,252 - WARNING - All requested RA, DEC, WAV points undefined (out of range) in SkyCube
# 2021-01-06 15:42:37,254 - INFO - Requested RA min: -4.268421, max: 6.092766
# 2021-01-06 15:42:37,255 - INFO - Requested DEC min: -4.785452, max: 3.640505
# 2021-01-06 15:42:37,256 - INFO - Requested WAV min: 17.492112, max: 21.040925 (in 840 bins)
# 2021-01-06 15:42:37,257 - INFO - Downsampling spectral columns of 3721 pixels. This may take long.
# {'RA': [-3.3, 3.3000000000000003], 'DEC': [-3.3, 3.3000000000000003], 'WAV': [11.437741058318277, 13.635283027586262]}
# 2021-01-06 15:42:39,774 - INFO - 3D downsampling took 2.5 seconds
# 2021-01-06 15:42:39,775 - INFO - Final helper interpolation...
# 2021-01-06 15:42:39,850 - INFO - All done
# 2021-01-06 15:42:39,870 - INFO - Reading 'PSF' model from './CDP/MIRI_FM_MIRIFULONG_4SHORT_PSF_07.02.00.fits'
# 2021-01-06 15:42:53,225 - INFO - Wrote skycube: 20210106_154151_mirisim/skycubes/skycube_seq1_4SHORT.fits
# 2021-01-06 15:42:53,226 - INFO - Simulating detector illumination for MRS exposures for pointing 1
# 2021-01-06 15:42:53,232 - INFO - Starting pySpecSimMiri
# 2021-01-06 15:42:53,249 - INFO - Simulating setup file /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2021-01-06 15:42:53,250 - INFO - Instrument setup starting.
# 2021-01-06 15:42:53,250 - INFO - Detector setup starting.
# 2021-01-06 15:42:53,251 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2021-01-06 15:42:53,252 - INFO - MRS light path simulation starting.
# 2021-01-06 15:42:53,253 - INFO - Simulating Instrument.
# 2021-01-06 15:42:53,259 - INFO - Simulating Detector.
# 2021-01-06 15:42:53,260 - INFO - Simulating Detector Mapping for channel ['3'] and band SHORT
# 2021-01-06 15:42:53,260 - INFO - Getting Coefficients and Substitute values
# 2021-01-06 15:42:53,262 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:42:53,616 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 15:42:53,667 - INFO - Valid cache found.
# 2021-01-06 15:42:53,668 - INFO - Starting Coordinate Transformation
# 2021-01-06 15:43:05,450 - INFO - Starting pixel projection with cache.
# 2021-01-06 15:44:17,626 - INFO - Mapping completed
# 2021-01-06 15:44:17,627 - INFO - Detector Intensity Array completed.
# 2021-01-06 15:44:17,942 - INFO - Reading 'FRINGE' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2021-01-06 15:44:18,084 - INFO - Reading 'PHOTOM' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_8B.04.00.fits'
# 2021-01-06 15:44:18,297 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 15:44:18,341 - INFO - Simulating Detector Mapping for channel ['4'] and band SHORT
# 2021-01-06 15:44:18,342 - INFO - Getting Coefficients and Substitute values
# 2021-01-06 15:44:18,343 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_DISTORTION_8B.05.01.fits'
# 2021-01-06 15:44:18,666 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 15:44:18,702 - INFO - Valid cache found.
# 2021-01-06 15:44:18,703 - INFO - Starting Coordinate Transformation
# 2021-01-06 15:44:26,188 - INFO - Starting pixel projection with cache.
# 2021-01-06 15:45:14,783 - INFO - Mapping completed
# 2021-01-06 15:45:14,784 - INFO - Detector Intensity Array completed.
# 2021-01-06 15:45:15,035 - INFO - Reading 'FRINGE' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_FRINGE_07.02.00.fits'
# 2021-01-06 15:45:15,133 - INFO - Reading 'PHOTOM' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_PHOTOM_8B.04.00.fits'
# 2021-01-06 15:45:15,231 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 15:45:15,263 - INFO - MRS light path simulation finished.
# 2021-01-06 15:45:15,270 - INFO - Added 3 Cube to output list
# 2021-01-06 15:45:15,271 - INFO - Added 4 Cube to output list
# 2021-01-06 15:45:15,485 - INFO - Wrote illumination model: 20210106_154151_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34SHORT.fits
# 2021-01-06 15:45:15,486 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2021-01-06 15:45:15,487 - INFO - Simulating MRS exposure 1
# 2021-01-06 15:45:15,491 - INFO - Running SCASim
# 2021-01-06 15:45:15,492 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2021-01-06 15:45:15,503 - INFO - Results will be returned in an exposure data model.
# 2021-01-06 15:45:15,515 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2021-01-06 15:45:15,516 - INFO -   with 10 integrations and ngroups=10 defined explicitly.
# 2021-01-06 15:45:15,517 - INFO -   Detector subarray mode is FULL.
# 2021-01-06 15:45:15,517 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2021-01-06 15:45:15,518 - INFO - Cosmic ray environment is SOLAR_MIN.
# 2021-01-06 15:45:15,519 - INFO - Reading cosmic ray library file: '/opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/miri/simulators/data/cosmic_rays/CRs_SiAs_470_SUNMIN_02.fits'
# 2021-01-06 15:45:15,560 - INFO - Simulation control flags:
# 2021-01-06 15:45:15,560 - INFO - 	Quantum efficiency simulation turned OFF.
# 2021-01-06 15:45:15,561 - INFO - 	Poisson noise simulation turned ON.
# 2021-01-06 15:45:15,562 - INFO - 	Read noise simulation turned ON.
# 2021-01-06 15:45:15,562 - INFO - 	Reference pixels simulation turned ON.
# 2021-01-06 15:45:15,563 - INFO - 	Bad pixels simulation turned ON.
# 2021-01-06 15:45:15,564 - INFO - 	Dark current simulation turned ON.
# 2021-01-06 15:45:15,565 - INFO - 	Flat-field simulation turned ON.
# 2021-01-06 15:45:15,566 - INFO - 	Amplifier bias and gain turned ON.
# 2021-01-06 15:45:15,566 - INFO - 	Detector non-linearity effects turned ON.
# 2021-01-06 15:45:15,567 - INFO - 	Detector drift effects turned ON.
# 2021-01-06 15:45:15,568 - INFO - 	Detector latency effects turned ON.
# 2021-01-06 15:45:15,568 - INFO - No output subarray mode. Input subarray mode assumed FULL.
# 2021-01-06 15:45:15,569 - INFO - Input subarray mode assumed FULL
# 2021-01-06 15:45:15,572 - INFO - Creating a new detector object for 1024 rows x 1024 columns.
# 2021-01-06 15:45:15,576 - INFO - Reading 'MASK' model from './CDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2021-01-06 15:45:15,641 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 15:45:39,308 - INFO - Reading DARK model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2021-01-06 15:45:42,492 - INFO - Reading 'PIXELFLAT' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_FLAT_8B.01.02.fits'
# 2021-01-06 15:45:42,564 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='SHORT'. An alternative is being used.
# 2021-01-06 15:45:42,579 - INFO - Reading 'LINEARITY' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits'
# 2021-01-06 15:45:42,859 - INFO - Reading 'READNOISE' model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2021-01-06 15:45:42,912 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 10 groups and 10 ints.
# 2021-01-06 15:45:43,357 - INFO - Simulating 10 integrations.
# 2021-01-06 15:45:43,366 - WARNING - ***Input flux array contains 11 negative values.
# 2021-01-06 15:45:43,462 - INFO - Simulating 10 groups for integration 1.
# 2021-01-06 15:45:45,370 - INFO - Simulating 10 groups for integration 2.
# 2021-01-06 15:45:47,225 - INFO - Simulating 10 groups for integration 3.
# 2021-01-06 15:45:49,074 - INFO - Simulating 10 groups for integration 4.
# 2021-01-06 15:45:50,957 - INFO - Simulating 10 groups for integration 5.
# 2021-01-06 15:45:52,844 - INFO - Simulating 10 groups for integration 6.
# 2021-01-06 15:45:54,765 - INFO - Simulating 10 groups for integration 7.
# 2021-01-06 15:45:56,820 - INFO - Simulating 10 groups for integration 8.
# 2021-01-06 15:45:58,744 - INFO - Simulating 10 groups for integration 9.
# 2021-01-06 15:46:00,600 - INFO - Simulating 10 groups for integration 10.
# 2021-01-06 15:46:02,430 - INFO - Adding the DARK calibration from ./CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2021-01-06 15:46:03,605 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits
# 2021-01-06 15:46:06,995 - INFO - Output subarray undefined or FULL. SUBSTRT=(1,1), SUBSIZE=(1032,1024)
# 2021-01-06 15:46:06,996 - INFO - WCS keywords defined as CRPIX1=0, CRPIX2=0
# 2021-01-06 15:46:10,455 - INFO - Exposure time 277.50s (duration 278.56s)
# 2021-01-06 15:46:17,262 - INFO - Wrote detector image: 20210106_154151_mirisim/det_images/det_image_seq1_MIRIFULONG_34SHORTexp1.fits
# 2021-01-06 15:46:17,263 - INFO - Simulating MRS exposure 2
# 2021-01-06 15:46:17,272 - INFO - Running SCASim
# 2021-01-06 15:46:17,273 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2021-01-06 15:46:17,285 - INFO - Results will be returned in an exposure data model.
# 2021-01-06 15:46:17,298 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2021-01-06 15:46:17,299 - INFO -   with 10 integrations and ngroups=10 defined explicitly.
# 2021-01-06 15:46:17,299 - INFO -   Detector subarray mode is FULL.
# 2021-01-06 15:46:17,300 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2021-01-06 15:46:17,301 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2021-01-06 15:46:17,302 - INFO - Simulation control flags:
# 2021-01-06 15:46:17,303 - INFO - 	Quantum efficiency simulation turned OFF.
# 2021-01-06 15:46:17,303 - INFO - 	Poisson noise simulation turned ON.
# 2021-01-06 15:46:17,305 - INFO - 	Read noise simulation turned ON.
# 2021-01-06 15:46:17,305 - INFO - 	Reference pixels simulation turned ON.
# 2021-01-06 15:46:17,306 - INFO - 	Bad pixels simulation turned ON.
# 2021-01-06 15:46:17,307 - INFO - 	Dark current simulation turned ON.
# 2021-01-06 15:46:17,307 - INFO - 	Flat-field simulation turned ON.
# 2021-01-06 15:46:17,308 - INFO - 	Amplifier bias and gain turned ON.
# 2021-01-06 15:46:17,309 - INFO - 	Detector non-linearity effects turned ON.
# 2021-01-06 15:46:17,309 - INFO - 	Detector drift effects turned ON.
# 2021-01-06 15:46:17,309 - INFO - 	Detector latency effects turned ON.
# 2021-01-06 15:46:17,310 - INFO - No output subarray mode. Input subarray mode assumed FULL.
# 2021-01-06 15:46:17,311 - INFO - Input subarray mode assumed FULL
# 2021-01-06 15:46:17,313 - INFO - Reading 'MASK' model from './CDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2021-01-06 15:46:17,367 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 15:46:17,510 - INFO - Reading DARK model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2021-01-06 15:46:19,478 - INFO - Reading 'PIXELFLAT' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_FLAT_8B.01.02.fits'
# 2021-01-06 15:46:19,540 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='SHORT'. An alternative is being used.
# 2021-01-06 15:46:19,552 - INFO - Reading 'LINEARITY' model from './CDP/MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits'
# 2021-01-06 15:46:19,761 - INFO - Reading 'READNOISE' model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2021-01-06 15:46:19,802 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 10 groups and 10 ints.
# 2021-01-06 15:46:20,116 - INFO - Simulating 10 integrations.
# 2021-01-06 15:46:20,123 - WARNING - ***Input flux array contains 11 negative values.
# 2021-01-06 15:46:20,175 - INFO - Simulating 10 groups for integration 1.
# 2021-01-06 15:46:22,048 - INFO - Simulating 10 groups for integration 2.
# 2021-01-06 15:46:23,909 - INFO - Simulating 10 groups for integration 3.
# 2021-01-06 15:46:25,907 - INFO - Simulating 10 groups for integration 4.
# 2021-01-06 15:46:27,830 - INFO - Simulating 10 groups for integration 5.
# 2021-01-06 15:46:29,724 - INFO - Simulating 10 groups for integration 6.
# 2021-01-06 15:46:31,576 - INFO - Simulating 10 groups for integration 7.
# 2021-01-06 15:46:33,420 - INFO - Simulating 10 groups for integration 8.
# 2021-01-06 15:46:35,254 - INFO - Simulating 10 groups for integration 9.
# 2021-01-06 15:46:37,086 - INFO - Simulating 10 groups for integration 10.
# 2021-01-06 15:46:38,888 - INFO - Adding the DARK calibration from ./CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2021-01-06 15:46:39,903 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34SHORT_LINEARITY_06.02.00.fits
# 2021-01-06 15:46:43,236 - INFO - Output subarray undefined or FULL. SUBSTRT=(1,1), SUBSIZE=(1032,1024)
# 2021-01-06 15:46:43,237 - INFO - WCS keywords defined as CRPIX1=0, CRPIX2=0
# 2021-01-06 15:46:45,580 - INFO - Exposure time 277.50s (duration 278.56s)
# 2021-01-06 15:46:52,100 - INFO - Wrote detector image: 20210106_154151_mirisim/det_images/det_image_seq1_MIRIFULONG_34SHORTexp2.fits
# 2021-01-06 15:46:52,101 - INFO - MIRI Simulation finished. Results have been saved to: 20210106_154151_mirisim

# %% [markdown]
# # 4) Examine some of the results
#
# Now that the MIRISim simulation has completed, lets examine the results.
#
#
# The first thing to note is that the outputs are placed in a date-labelled directory taking the form  <code> YYYYMMDD_hhmmss_mirisim</code>.  The name of the output directory is given in the last line of the MIRISim log above.  Because the output directory is date-labelled, we can quantify which was the most recent run of MIRISim, and find its output directory using <code>glob.glob</code>

# %%
outputdir = sorted(glob.glob('*_*_mirisim'),key=os.path.getmtime)[-1]    #[-1] takes the last entry found

outputDirContents = os.listdir(outputdir)

directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]
files = [name for name in outputDirContents if not os.path.isdir(os.path.join(outputdir,name))]

print('The subdirectories in the outputdirectory are:\n{}'.format(directories))
print('The files in the outputdirectory are:\n{}'.format(files))
# Out:
# The subdirectories in the outputdirectory are:
# ['det_images', 'skycubes', 'illum_models']
# The files in the outputdirectory are:
# ['simulator.ini', 'scene.ini', 'mrs_recommended_dither.dat', 'simulation.ini', 'mirisim.log']

# %% [markdown]
# The files contain the log which was also output to the terminal (<code> mirisim.log</code>) and copies of the .ini files used (or created from python inputs) to create the simulation. These versions of the .ini files can be used to re-create the run of the simulation
#
# The directories contain various outputs of MIRISim:
#
# * **<code> skycubes </code>** houses a 3D representation of the input scene to the MRS simulation (skycubes are not generated for imager or LRS simulations). This cube has not been processed by MIRISim, it is simply a gridded (spatially and spectrally) version of the input scene.
# * **<code> illum_models </code>** houses FITS images of the illuminations sent to the detector (sent to SCAsim - the simulator of the Sensor Chip Assembly).  This should have the same format as the detector image, but without all of the detector effects and noise. There are FITS files produced for each exposure and dither position
# * **<code> det_images </code>** houses FITS images of the final outputs of MIRISim. These detector images have all of the detector effects and noise incorporated. The number of detector images should be the same as the number of illumination models.
#
# The headers of the detector images are formatted for ingest into the JWST pipeline.
#
# Below is a small code snippet used to draw the images.  it needs to be run, but doesn't produce any output directly (it's called later to show the output images)

# %%
def show_outputs(MIRISim_outputdir,output_type):
    '''
    plot the specified channel of the MIRISim outputs
    :param MIRISim_outputdir:  
        name of the date-labelled dir. holding the MIRISIM outputs
    :param output_type: 
        type of output to process 
        (e.g. illum_models, det_images or skycubes)
    '''
    
    infits = glob.glob('{}/{}/*.fits'.format(MIRISim_outputdir,output_type))[0]
    
    hdulist = fits.open(infits)
    
    if output_type.lower() == 'skycubes': 
        hdu_index = 0
        datashape = hdulist[hdu_index].data.shape
        central_chan = datashape[0]/2
        plt.imshow(hdulist[hdu_index].data[central_chan,:,:],
           origin = 'lower', interpolation = 'nearest',cmap = cm.viridis)
        plt.title('channel {} of {}'.format(central_chan,infits.split('/')[-1]))
        plt.xlabel(hdulist[hdu_index].header['ctype1'])
        plt.ylabel(hdulist[hdu_index].header['ctype2'])
    else:
        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data
            
        
        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest')
        plt.title('{}'.format(infits.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')


    plt.colorbar()
    plt.savefig('MRS_{}.png'.format(output_type))

# %% [markdown]
# ### Viewing a slice of the skycube
#
# Below, we show an image of the central channel of one of the skycubes generated by MIRISim

# %%
#show_outputs(outputdir,'skycubes')
# Doesn't appear to be working.

# %% [markdown]
# ### Viewing an illumination model
#
# Below shows an example of an output illumination model

# %%
show_outputs(outputdir,'illum_models')

# %% [markdown]
# ### Viewing the final detector image
#
# The detector images are the final output of MIRISim, and have data structures and formatting consistent with what will come from MIRI itself. The data format is JWST pipeline ready.  Below an example image of the last frame of the last integration is shown. The units are <code>DN</code>.
#
# Additionally, below the FITS header information for the SCIENCE extension is listed.
#
# This is the "Level 1" data.

# %%
show_outputs(outputdir,'det_images')

infits = glob.glob('{}/det_images/*.fits'.format(outputdir))[0]
hdulist = fits.open(infits)
hdulist[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    4 / number of array dimensions
# NAXIS1  =                 1032
# NAXIS2  =                 1024
# NAXIS3  =                   10
# NAXIS4  =                   10
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
#
#         Information about the coordinates in the file
#
# RADESYS = 'ICRS    '           / Name of the coordinate reference frame
#
#         Information about the data array
#
# BUNIT   = 'DN      '           / Units of the data array
#
#         Spacecraft pointing information
#
# RA_V1   =   0.1401034477250189 / [deg] RA of telescope V1 axis
# DEC_V1  =  0.08855511799505092 / [deg] Dec of telescope V1 axis
# PA_V3   =                 -0.0 / [deg] Position angle of telescope V3 axis
#
#         WCS parameters
#
# WCSAXES =                    3 / number of World Coordinate System axes
# CRPIX1  =                    0 / axis 1 coordinate of the reference pixel
# CRPIX2  =                    0 / axis 2 coordinate of the reference pixel
# CRPIX3  =                    0 / axis 3 coordinate of the reference pixel
# CRVAL1  =                  0.0 / first axis value at the reference pixel
# CRVAL2  =                  0.0 / second axis value at the reference pixel
# CRVAL3  =                  0.0 / third axis value at the reference pixel
# CTYPE1  = '' / first axis coordinate type
# CTYPE2  = '' / second axis coordinate type
# CTYPE3  = '' / third axis coordinate type
# CUNIT1  = '' / first axis units
# CUNIT2  = '' / second axis units
# CUNIT3  = '' / third axis units
# CDELT1  =                  1.0 / first axis increment per pixel
# CDELT2  =                  1.0 / second axis increment per pixel
# CDELT3  =                  1.0 / third axis increment per pixel
# V2_REF  =   -503.6544721447135 / [arcsec] Telescope v2 coordinate of the referen
# V3_REF  =    -318.742450697324 / [arcsec] Telescope v3 coordinate of the referen
# VPARITY =                   -1 / Relative sense of rotation between Ideal xy and
# V3I_YANG=                  0.0 / [deg] Angle from V3 axis to Ideal y axis
# RA_REF  = 0.000199427684820724 / [deg] Right ascension of the reference point
# DEC_REF = 1.55483569053653E-05 / [deg] Declination of the reference point
# ROLL_REF=                 -0.0 / [deg] V3 roll angle at the ref point (N over E)
# EXTVER  =                    1 / extension value

# %% [markdown]
# ### Next Steps
# * Run through MRS pipeline to test output products.
# * Patrick Kavanagh has provided some excellent notebooks at, https://github.com/PaddyKavanagh
# * For this dataset, Alistair adapted build7.2.1/MRS_pipeline.ipynb which runs all pipeline steps up to cube building and spectrum extraction.
