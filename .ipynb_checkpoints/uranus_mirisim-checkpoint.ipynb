# %% [markdown]
# ## Notebook to Simulate MIRI Observations based on NEMESIS Outputs
#
# When launching the notebook, make sure in the right Anaconda environment. i.e. type
#
# <code> source activate mirisim </code>
#
# in the terminal before starting the notebook.  This is based on contributions from A. Glasse, N. Rowe-Gurney, and the MIRISim walkthrough.
#
# Mirisim can be run via notebooks or directly as a callable python package.
#
# L.N. Fletcher (2021)
#
# ### Open Questions:
# * Am I correctly mapping the NEMESIS cubes to detector, disperser, MRS sub-band?
# * I am providing only a single MRS sub-band to the simulator, and yet both halves of the detector frame seem to have contents (e.g., CH1/2 for 'SW' detector; CH4/3 for 'LW' detector) - why?
# * Background is not yet included - what are the units?  Are the expected units uJy/arcsec^2?

# %%
# Set up MIRISIM and import useful tools:
from mirisim import MiriSimulation

# import the configuration file parsers so they can be written to file
from mirisim.config_parser import SimConfig, SceneConfig, SimulatorConfig
#from mirisim.skysim import wrap_pysynphot as wS

# import scene component generators
from mirisim.skysim import Background

#other tools to be used
import numpy as np
import glob                 # glob is used to find the output directory
import os                   # for listing directory contents
from astropy.io import fits # for reading FITS file contents

import matplotlib.pyplot as plt    # to display images
from matplotlib import colors,cm
# %matplotlib inline   

import astropy.units as u

# %% [markdown]
# ## 1) Read & Modify the Uranus Scene:
#
# The direct cubes calculated by NEMESIS are subdivided into 12 seperate channels, each with an associated wavelength grid that doesn't appear to be used right now.  In the block that follows, the header of the FITS file is updated to be recognised by the MIRISim code.
#
# #### Mapping Simulation Cube to MRS Parameters
#
# Detector = Specify Dectector (SW = channels 1,2, LW= channels 3,4)
# Channel = channels 1-4 (also called MRS subbands)
# Disperser = Specify disperser to use (SHORT/MEDIUM/LONG, aka A/B/C)
#
# 1. SW 1 SHORT/A
# 1. SW 1 MEDIUM/B
# 1. SW 1 LONG/C
# 1. SW 2 SHORT/A
# 1. SW 2 MEDIUM/B
# 1. SW 2 LONG/C
# 1. LW 3 SHORT/A
# 1. LW 3 MEDIUM/B
# 1. LW 3 LONG/C
# 1. LW 4 SHORT/A
# 1. LW 4 MEDIUM/B
# 1. LW 4 LONG/C
#
# ![image.png](attachment:image.png)

# %%
# Mapping the Cube to the MRS sub-band, disperser, and detector:
ichan=8

if ichan==1:
    ConfigPath = 'MRS_1SHORT'
    disperser = 'SHORT'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan1_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan1_wave.fits"
if ichan==2:
    ConfigPath = 'MRS_1MEDIUM'
    disperser = 'MEDIUM'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan2_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan2_wave.fits"
if ichan==3:
    ConfigPath = 'MRS_1LONG'
    disperser = 'LONG'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan3_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan3_wave.fits"
if ichan==4:
    ConfigPath = 'MRS_2SHORT'
    disperser = 'SHORT'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan4_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan4_wave.fits"
if ichan==5:
    ConfigPath = 'MRS_2MEDIUM'
    disperser = 'MEDIUM'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan5_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan5_wave.fits"
if ichan==6:
    ConfigPath = 'MRS_2LONG'
    disperser = 'LONG'
    detector = 'SW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan6_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan6_wave.fits"
if ichan==7:
    ConfigPath = 'MRS_3SHORT'
    disperser = 'SHORT'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan7_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan7_wave.fits"
if ichan==8:
    ConfigPath = 'MRS_3MEDIUM'
    disperser = 'MEDIUM'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan8_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan8_wave.fits"
if ichan==9:
    ConfigPath = 'MRS_3LONG'
    disperser = 'LONG'
    detector = 'LW'    
    u_raw_fits = "NEMESISCubes/uranusMRS_chan9_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan9_wave.fits"
if ichan==10:
    ConfigPath = 'MRS_4SHORT'
    disperser = 'SHORT'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan10_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan10_wave.fits"
if ichan==11:
    ConfigPath = 'MRS_4MEDIUM'
    disperser = 'MEDIUM'
    detector = 'LW'
    u_raw_fits = "NEMESISCubes/uranusMRS_chan11_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan11_wave.fits"
if ichan==12:
    ConfigPath = 'MRS_4LONG'
    disperser = 'LONG'
    detector = 'LW'    
    u_raw_fits = "NEMESISCubes/uranusMRS_chan12_radJy.fits"
    wav_fits = "NEMESISCubes/uranusMRS_chan12_wave.fits"
    
print("Channel:",ichan)
print("Disperser:",disperser)
print("Optical Path:",ConfigPath)
print("Detector",detector)
    
hdu_list = fits.open(u_raw_fits)
hdu = hdu_list[0]


whdu_list = fits.open(wav_fits)
whdu = whdu_list[0]

wavegrid=whdu.data

vmin=np.min(wavegrid)
vmax=np.max(wavegrid)
nwav=len(wavegrid)
dwave=(vmax-vmin)/nwav

print("Wavelengths:",vmin,vmax,nwav)
print("Dispersion:",dwave)

crpix = (1, 1, 1)
crval = (0., 0., vmin)
dpix = 0.11                 # Pixel size in arcsec
#dwave = 0.00073             # micron (bw / 1300 ~
cdelt = (dpix, dpix, dwave)

hdu.header['CRVAL1'] = crval[0]
hdu.header['CRPIX1'] = crpix[0]
hdu.header['CDELT1'] = cdelt[0]
hdu.header['CUNIT1'] = u.arcsec.to_string()
hdu.header['CTYPE1'] = 'RA---TAN'

hdu.header['CRVAL2'] = crval[1]
hdu.header['CRPIX2'] = crpix[1]
hdu.header['CDELT2'] = cdelt[1]
hdu.header['CUNIT2'] = u.arcsec.to_string()
hdu.header['CTYPE2'] = 'DEC--TAN'

hdu.header['CRVAL3'] = crval[2]
hdu.header['CRPIX3'] = crpix[2]
hdu.header['CDELT3'] = cdelt[2]
hdu.header['CUNIT3'] = u.micron.to_string()
hdu.header['CTYPE3'] = 'WAVE    '

hdu.header['UNITS'] = 'uJy / arcsec2'  #u.microjansky.to_string()

hdu.data = np.multiply(hdu.data, 1.0e6)  # NEMESIS data in Jy/arcsec^2, multiply to get microJy/arcsec^2

run_file_name = 'run_scene.fits'
if os.path.isfile(run_file_name):
    os.remove(run_file_name)
hdu.writeto(run_file_name)

print("Modified FITS file created")
# Out:
# Channel: 8
# Disperser: MEDIUM
# Optical Path: MRS_3MEDIUM
# Detector LW
# Wavelengths: 13.22 15.7564 689
# Dispersion: 0.0036812769830313406
# Modified FITS file created

# %%
### create a low level background for the scene
bg = Background(level='low', gradient = 5., pa = 15.)  # Gradient=0 == contant background)

# NOTE!  bg is currently unused, and needs to be added to the scene or FITS image (see below).
# Out:
# 2021-01-06 16:12:02,384 - INFO - Initializing Background

# %% [markdown]
# # 2) Initialise the Simulation Parameters
#
# This is where the parameters for the MRS simulation get set. Note that for internal consistency in MIRISim, all settings (including those not used in the MRS simulation here) must be set. Those not being used in this simulation are labelled with <code> NOT USED HERE </code> in the comments of each line
#
# MIRISim then needs a configuration file to run.
# Questions:
# * Should we change ConfigPath for each subband?  Yes, doesn't make sense otherwise.
# * Do we need to change the imager filter when using the MRS?  No, don't think it's used.

# %%
sim_config = SimConfig.makeSim(
    name = 'Uranus.test',           # name given to simulation,
    scene = 'uranus_scene',         # name of scene file to input,
    rel_obsdate = 0.0,              # relative observation date (0 = launch, 1 = end of 5 yrs),
    POP = 'MRS',                    # Component on which to center (Imager or MRS),
    ConfigPath = ConfigPath,      # Configure the Optical path (MRS sub-band)
    Dither = False,                 # Dither  - use false for test case
    StartInd = 1,                   # Start index for dither pattern
    NDither = 2,                    # Number of dither positions (12)
    DitherPat = 'mrs_recommended_dither.dat', # dither pattern to use   - If using REULEAUX need to update,
    disperser = disperser,        # Which disperser to use (SHORT/MEDIUM/LONG)
    detector = detector,            # Specify Channel (SW = channels 1,2, LW= channels 3,4)
    mrs_mode = 'FAST',          # MRS read mode (default is SLOW. ~ 24s)
    mrs_exposures = 2,          # MRS number of exposures
    mrs_integrations = 10,      # MRS number of integrations
    mrs_frames = 10,            # MRS number of groups (for MIRI, # Groups = # Frames)
    ima_exposures = 1,          # IMA number of exposures,
    ima_integrations = 10,      # IMA number of integrations (5)",
    ima_frames = 10,            # IMA number of groups (for MIRI, # Groups = # Frames),
    ima_mode = 'FAST',          # IMA read mode (default is FAST ~ 2.3 s),
    filter = 'F770W',           # IMA Filter to use,
    readDetect = 'FULL'         # Portion of detector to read out,
)

simulator_config = SimulatorConfig.from_default()
scene_config = SceneConfig('uranus_scene.ini')

### Suggestion from Alistair for adding background (doesn't work).
#scene_config = SceneConfig('uranus_scene.ini',background=bg)
# Export the simulation setup to a file.
sim_config.write('MRS_simulation.ini')


print("Simulation configuration complete.")
# Out:
# 2021-01-06 16:12:05,613 - INFO - Using scene configuration: uranus_scene.ini
# MRS_simulation.ini exists, overwrite (y/[n])?y
# Simulation configuration complete.

# %% [markdown]
# # 3) Run the simulation
#
# Now that the scene and the setup of the simulation have been set, we can run the simulation.
#
# the last step is to setup the defaults for internal things like CDPs.
# Outputs to unique directory format: YYYYMMDD_HHMMSS_mirisim

# %%
sim = MiriSimulation(sim_config, scene_config, simulator_config)

print("Running simulation:")
sim.run()
# Out:
# 2021-01-06 16:12:15,118 - INFO - MIRISim version: 2.3.0
# 2021-01-06 16:12:15,120 - INFO - MIRI Simulation started.
# 2021-01-06 16:12:15,122 - INFO - Output will be saved to: 20210106_161215_mirisim
# 2021-01-06 16:12:15,123 - INFO - Storing configs in output directory.
# 2021-01-06 16:12:15,130 - INFO - Storing dither pattern in output directory.
# 2021-01-06 16:12:15,134 - WARNING - Environment variable CDP_DIR is not set. Will look up / store CDP files at ./CDP
# 2021-01-06 16:12:15,135 - INFO -
# 2021-01-06 16:12:15,138 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# 2021-01-06 16:12:15,255 - INFO -
# 2021-01-06 16:12:15,256 - INFO - 	*** Detector hard reset. NOTE: All latency and drift data will be erased.
# Running simulation:
# 2021-01-06 16:12:15,399 - INFO - Setting up simulated Observation, with following settings:
# 2021-01-06 16:12:15,401 - INFO - Configuration Path: MRS_3MEDIUM
# 2021-01-06 16:12:15,402 - INFO - Primary optical path: MRS
# 2021-01-06 16:12:15,403 - INFO - MRS detector: LW
# 2021-01-06 16:12:15,404 - INFO - MRS band: MEDIUM
# 2021-01-06 16:12:15,405 - INFO - MRS detector readout mode: FAST
# 2021-01-06 16:12:15,406 - INFO - MRS detector # exposures: 2
# 2021-01-06 16:12:15,407 - INFO - MRS detector # integrations: 10
# 2021-01-06 16:12:15,408 - INFO - MRS detector # frames: 10
# 2021-01-06 16:12:15,409 - INFO - Parsing: input fits
# 2021-01-06 16:12:15,409 - INFO - Initializing Skycube
# 2021-01-06 16:12:15,411 - INFO - Loading external scene from FITS run_scene.fits
# 2021-01-06 16:12:15,586 - INFO - Aligning the centre of the fits file with the centre of the scene
# 2021-01-06 16:12:15,587 - INFO - Simulating a single pointing.
# /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/gwcs/wcs.py:131: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   transforms = np.array(self._pipeline[from_ind: to_ind])[:, 1].copy()
# 2021-01-06 16:12:15,596 - INFO - Creating pointing for position 1
# 2021-01-06 16:12:15,598 - INFO - Creating exposure event for position 1
# 2021-01-06 16:12:15,600 - INFO -  Retrieving CDP file
# 2021-01-06 16:12:15,601 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:12:15,602 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits' ...
# 2021-01-06 16:12:50,018 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:12:50,421 - INFO - Observation simulation started.
# 2021-01-06 16:12:50,422 - INFO - Simulating ExposureEvent for pointing 1
# 2021-01-06 16:12:50,423 - INFO - Simulating MRS exposures for pointing 1
# 2021-01-06 16:12:50,424 - INFO - Creating skycubes for MRS exposures for pointing 1
# 2021-01-06 16:12:50,426 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:12:50,833 - INFO - Downsampling spectral columns of 3721 pixels. This may take long.
# 2021-01-06 16:12:53,484 - INFO - 3D downsampling took 2.6 seconds
# 2021-01-06 16:12:53,485 - INFO - Final helper interpolation...
# 2021-01-06 16:12:53,586 - INFO - All done
# 2021-01-06 16:12:53,623 - INFO -  Retrieving CDP file
# 2021-01-06 16:12:53,624 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_3MEDIUM_PSF_07.02.00.fits'
# 2021-01-06 16:12:53,625 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_3MEDIUM_PSF_07.02.00.fits' ...
# 2021-01-06 16:13:51,579 - INFO - Reading 'PSF' model from './CDP/MIRI_FM_MIRIFULONG_3MEDIUM_PSF_07.02.00.fits'
# WARNING: Model is linear in parameters; consider using linear fitting methods. [astropy.modeling.fitting]
# WARNING:astropy:Model is linear in parameters; consider using linear fitting methods.
# 2021-01-06 16:14:15,748 - INFO - Wrote skycube: 20210106_161215_mirisim/skycubes/skycube_seq1_3MEDIUM.fits
# 2021-01-06 16:14:15,753 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:14:16,159 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:14:16,561 - WARNING - All requested RA, DEC, WAV points undefined (out of range) in SkyCube
# 2021-01-06 16:14:16,563 - INFO - Requested RA min: -4.853075, max: 5.769413
# 2021-01-06 16:14:16,564 - INFO - Requested DEC min: -4.458531, max: 3.965374
# 2021-01-06 16:14:16,566 - INFO - Requested WAV min: 20.232443, max: 24.337560 (in 840 bins)
# 2021-01-06 16:14:16,567 - INFO - Downsampling spectral columns of 3721 pixels. This may take long.
# {'RA': [-3.3, 3.3000000000000003], 'DEC': [-3.3, 3.3000000000000003], 'WAV': [13.21631899004578, 15.749037554371341]}
# 2021-01-06 16:14:18,764 - INFO - 3D downsampling took 2.2 seconds
# 2021-01-06 16:14:18,765 - INFO - Final helper interpolation...
# 2021-01-06 16:14:18,825 - INFO - All done
# 2021-01-06 16:14:18,841 - INFO -  Retrieving CDP file
# 2021-01-06 16:14:18,841 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_4MEDIUM_PSF_07.02.00.fits'
# 2021-01-06 16:14:18,842 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_4MEDIUM_PSF_07.02.00.fits' ...
# 2021-01-06 16:15:32,479 - INFO - Reading 'PSF' model from './CDP/MIRI_FM_MIRIFULONG_4MEDIUM_PSF_07.02.00.fits'
# 2021-01-06 16:15:45,360 - INFO - Wrote skycube: 20210106_161215_mirisim/skycubes/skycube_seq1_4MEDIUM.fits
# 2021-01-06 16:15:45,364 - INFO - Simulating detector illumination for MRS exposures for pointing 1
# 2021-01-06 16:15:45,378 - INFO - Starting pySpecSimMiri
# 2021-01-06 16:15:45,406 - INFO - Simulating setup file /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/pySpecSim/MIRI/MiriSetupData.py
# 2021-01-06 16:15:45,407 - INFO - Instrument setup starting.
# 2021-01-06 16:15:45,409 - INFO - Detector setup starting.
# 2021-01-06 16:15:45,411 - INFO - Could not find value for numBlind Columns, assuming 4.
# 2021-01-06 16:15:45,413 - INFO - MRS light path simulation starting.
# 2021-01-06 16:15:45,414 - INFO - Simulating Instrument.
# 2021-01-06 16:15:45,422 - INFO - Simulating Detector.
# 2021-01-06 16:15:45,423 - INFO - Simulating Detector Mapping for channel ['3'] and band MEDIUM
# 2021-01-06 16:15:45,423 - INFO - Getting Coefficients and Substitute values
# 2021-01-06 16:15:45,426 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:15:45,835 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 16:15:45,840 - INFO - No valid cache found, will proceed slowly.
# 2021-01-06 16:15:45,884 - INFO - Starting Coordinate Transformation
# 2021-01-06 16:15:57,849 - INFO - Starting pixel projection, it may be a while.
# /opt/anaconda3/envs/mirisim/lib/python3.7/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# 2021-01-06 16:26:29,443 - INFO - Mapping completed
# 2021-01-06 16:26:29,445 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 16:26:29,688 - INFO - Detector Intensity Array completed.
# 2021-01-06 16:26:30,021 - INFO -  Retrieving CDP file
# 2021-01-06 16:26:30,022 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2021-01-06 16:26:30,023 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits' ...
# 2021-01-06 16:26:38,270 - INFO - Reading 'FRINGE' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2021-01-06 16:26:38,409 - INFO -  Retrieving CDP file
# 2021-01-06 16:26:38,411 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_8B.04.00.fits'
# 2021-01-06 16:26:38,412 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_8B.04.00.fits' ...
# 2021-01-06 16:26:56,964 - INFO - Reading 'PHOTOM' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_8B.04.00.fits'
# 2021-01-06 16:26:57,086 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 16:26:57,131 - INFO - Simulating Detector Mapping for channel ['4'] and band MEDIUM
# 2021-01-06 16:26:57,132 - INFO - Getting Coefficients and Substitute values
# 2021-01-06 16:26:57,133 - INFO - Reading 'DISTORTION' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_DISTORTION_8B.05.01.fits'
# 2021-01-06 16:26:57,500 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 16:26:57,502 - INFO - No valid cache found, will proceed slowly.
# 2021-01-06 16:26:57,535 - INFO - Starting Coordinate Transformation
# 2021-01-06 16:27:04,965 - INFO - Starting pixel projection, it may be a while.
# 2021-01-06 16:34:28,293 - INFO - Mapping completed
# 2021-01-06 16:34:28,295 - INFO - Cannot find environmental variable : CDP_DIR, proceeding with local storage.
# 2021-01-06 16:34:28,454 - INFO - Detector Intensity Array completed.
# 2021-01-06 16:34:28,710 - INFO - Reading 'FRINGE' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FRINGE_07.02.00.fits'
# 2021-01-06 16:34:28,817 - INFO - Reading 'PHOTOM' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_PHOTOM_8B.04.00.fits'
# 2021-01-06 16:34:28,931 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 16:34:28,966 - INFO - MRS light path simulation finished.
# 2021-01-06 16:34:28,983 - INFO - Added 3 Cube to output list
# 2021-01-06 16:34:28,983 - INFO - Added 4 Cube to output list
# 2021-01-06 16:34:29,166 - INFO - Wrote illumination model: 20210106_161215_mirisim/illum_models/illum_model_seq1_MIRIFULONG_34MEDIUM.fits
# 2021-01-06 16:34:29,167 - INFO - Simulating integrated detector images for MRS exposures for pointing 1
# 2021-01-06 16:34:29,168 - INFO - Simulating MRS exposure 1
# 2021-01-06 16:34:29,173 - INFO - Running SCASim
# 2021-01-06 16:34:29,174 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2021-01-06 16:34:29,186 - INFO - Results will be returned in an exposure data model.
# 2021-01-06 16:34:29,201 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2021-01-06 16:34:29,202 - INFO -   with 10 integrations and ngroups=10 defined explicitly.
# 2021-01-06 16:34:29,202 - INFO -   Detector subarray mode is FULL.
# 2021-01-06 16:34:29,204 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2021-01-06 16:34:29,205 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2021-01-06 16:34:29,206 - INFO - Simulation control flags:
# 2021-01-06 16:34:29,207 - INFO - 	Quantum efficiency simulation turned OFF.
# 2021-01-06 16:34:29,208 - INFO - 	Poisson noise simulation turned ON.
# 2021-01-06 16:34:29,208 - INFO - 	Read noise simulation turned ON.
# 2021-01-06 16:34:29,209 - INFO - 	Reference pixels simulation turned ON.
# 2021-01-06 16:34:29,210 - INFO - 	Bad pixels simulation turned ON.
# 2021-01-06 16:34:29,210 - INFO - 	Dark current simulation turned ON.
# 2021-01-06 16:34:29,211 - INFO - 	Flat-field simulation turned ON.
# 2021-01-06 16:34:29,211 - INFO - 	Amplifier bias and gain turned ON.
# 2021-01-06 16:34:29,212 - INFO - 	Detector non-linearity effects turned ON.
# 2021-01-06 16:34:29,212 - INFO - 	Detector drift effects turned ON.
# 2021-01-06 16:34:29,213 - INFO - 	Detector latency effects turned ON.
# 2021-01-06 16:34:29,213 - INFO - No output subarray mode. Input subarray mode assumed FULL.
# 2021-01-06 16:34:29,214 - INFO - Input subarray mode assumed FULL
# 2021-01-06 16:34:29,218 - INFO - Reading 'MASK' model from './CDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2021-01-06 16:34:29,270 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 16:34:29,343 - INFO - Reading DARK model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2021-01-06 16:34:32,693 - INFO -  Retrieving CDP file
# 2021-01-06 16:34:32,694 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_34MEDIUM_FLAT_8B.01.02.fits'
# 2021-01-06 16:34:32,695 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FLAT_8B.01.02.fits' ...
# 2021-01-06 16:34:51,876 - INFO - Reading 'PIXELFLAT' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FLAT_8B.01.02.fits'
# 2021-01-06 16:34:51,938 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='MEDIUM'. An alternative is being used.
# 2021-01-06 16:34:51,953 - INFO -  Retrieving CDP file
# 2021-01-06 16:34:51,954 - INFO -   from sftp 'www.miricle.org/.../MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits'
# 2021-01-06 16:34:51,955 - INFO -   to cache './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits' ...
# 2021-01-06 16:35:08,612 - INFO - Reading 'LINEARITY' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits'
# 2021-01-06 16:35:08,838 - INFO - Reading 'READNOISE' model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2021-01-06 16:35:08,895 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 10 groups and 10 ints.
# 2021-01-06 16:35:09,214 - INFO - Simulating 10 integrations.
# 2021-01-06 16:35:09,222 - WARNING - ***Input flux array contains 2 negative values.
# 2021-01-06 16:35:09,379 - INFO - Simulating 10 groups for integration 1.
# 2021-01-06 16:35:11,337 - INFO - Simulating 10 groups for integration 2.
# 2021-01-06 16:35:13,282 - INFO - Simulating 10 groups for integration 3.
# 2021-01-06 16:35:15,225 - INFO - Simulating 10 groups for integration 4.
# 2021-01-06 16:35:17,139 - INFO - Simulating 10 groups for integration 5.
# 2021-01-06 16:35:19,056 - INFO - Simulating 10 groups for integration 6.
# 2021-01-06 16:35:21,003 - INFO - Simulating 10 groups for integration 7.
# 2021-01-06 16:35:22,939 - INFO - Simulating 10 groups for integration 8.
# 2021-01-06 16:35:24,884 - INFO - Simulating 10 groups for integration 9.
# 2021-01-06 16:35:26,813 - INFO - Simulating 10 groups for integration 10.
# 2021-01-06 16:35:28,686 - INFO - Adding the DARK calibration from ./CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2021-01-06 16:35:29,808 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits
# 2021-01-06 16:35:33,402 - INFO - Output subarray undefined or FULL. SUBSTRT=(1,1), SUBSIZE=(1032,1024)
# 2021-01-06 16:35:33,403 - INFO - WCS keywords defined as CRPIX1=0, CRPIX2=0
# 2021-01-06 16:35:36,922 - INFO - Exposure time 277.50s (duration 278.56s)
# 2021-01-06 16:35:44,019 - INFO - Wrote detector image: 20210106_161215_mirisim/det_images/det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits
# 2021-01-06 16:35:44,020 - INFO - Simulating MRS exposure 2
# 2021-01-06 16:35:44,031 - INFO - Running SCASim
# 2021-01-06 16:35:44,032 - INFO - Simulating  detector readout for MIRIFULONG from illumination data model of shape (1024, 1024).
# 2021-01-06 16:35:44,045 - INFO - Results will be returned in an exposure data model.
# 2021-01-06 16:35:44,056 - INFO -   Detector readout mode is FAST (samplesum=1, sampleskip=0, nframe=1, groupgap=0)
# 2021-01-06 16:35:44,057 - INFO -   with 10 integrations and ngroups=10 defined explicitly.
# 2021-01-06 16:35:44,057 - INFO -   Detector subarray mode is FULL.
# 2021-01-06 16:35:44,058 - INFO - Detector temperature = 6.70 K (which affects dark current and read noise).
# 2021-01-06 16:35:44,059 - INFO - Cosmic ray environment is SOLAR_MIN. (No change.)
# 2021-01-06 16:35:44,060 - INFO - Simulation control flags:
# 2021-01-06 16:35:44,061 - INFO - 	Quantum efficiency simulation turned OFF.
# 2021-01-06 16:35:44,062 - INFO - 	Poisson noise simulation turned ON.
# 2021-01-06 16:35:44,063 - INFO - 	Read noise simulation turned ON.
# 2021-01-06 16:35:44,063 - INFO - 	Reference pixels simulation turned ON.
# 2021-01-06 16:35:44,064 - INFO - 	Bad pixels simulation turned ON.
# 2021-01-06 16:35:44,065 - INFO - 	Dark current simulation turned ON.
# 2021-01-06 16:35:44,065 - INFO - 	Flat-field simulation turned ON.
# 2021-01-06 16:35:44,066 - INFO - 	Amplifier bias and gain turned ON.
# 2021-01-06 16:35:44,066 - INFO - 	Detector non-linearity effects turned ON.
# 2021-01-06 16:35:44,066 - INFO - 	Detector drift effects turned ON.
# 2021-01-06 16:35:44,067 - INFO - 	Detector latency effects turned ON.
# 2021-01-06 16:35:44,068 - INFO - No output subarray mode. Input subarray mode assumed FULL.
# 2021-01-06 16:35:44,068 - INFO - Input subarray mode assumed FULL
# 2021-01-06 16:35:44,070 - INFO - Reading 'MASK' model from './CDP/MIRI_FM_MIRIFULONG_34_MASK_07.02.01.fits'
# 2021-01-06 16:35:44,119 - INFO - Reading 'GAIN' model from './CDP/MIRI_FM_MIRIFULONG_34_GAIN_04.00.00.fits'
# 2021-01-06 16:35:44,280 - INFO - Reading DARK model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits'
# 2021-01-06 16:35:46,705 - INFO - Reading 'PIXELFLAT' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_FLAT_8B.01.02.fits'
# 2021-01-06 16:35:46,776 - WARNING - Could not find exact match for pixel flat-field for detector MIRIFULONG with FAST mode with band='MEDIUM'. An alternative is being used.
# 2021-01-06 16:35:46,789 - INFO - Reading 'LINEARITY' model from './CDP/MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits'
# 2021-01-06 16:35:47,621 - INFO - Reading 'READNOISE' model from './CDP/MIRI_FM_MIRIFULONG_FAST_34_READNOISE_07.01.00.fits'
# 2021-01-06 16:35:47,662 - INFO - Creating exposure_data with 1280 rows x 1032 columns plus 10 groups and 10 ints.
# 2021-01-06 16:35:47,972 - INFO - Simulating 10 integrations.
# 2021-01-06 16:35:47,979 - WARNING - ***Input flux array contains 2 negative values.
# 2021-01-06 16:35:48,029 - INFO - Simulating 10 groups for integration 1.
# 2021-01-06 16:35:50,015 - INFO - Simulating 10 groups for integration 2.
# 2021-01-06 16:35:52,010 - INFO - Simulating 10 groups for integration 3.
# 2021-01-06 16:35:53,981 - INFO - Simulating 10 groups for integration 4.
# 2021-01-06 16:35:55,984 - INFO - Simulating 10 groups for integration 5.
# 2021-01-06 16:35:57,967 - INFO - Simulating 10 groups for integration 6.
# 2021-01-06 16:35:59,951 - INFO - Simulating 10 groups for integration 7.
# 2021-01-06 16:36:01,928 - INFO - Simulating 10 groups for integration 8.
# 2021-01-06 16:36:03,863 - INFO - Simulating 10 groups for integration 9.
# 2021-01-06 16:36:05,770 - INFO - Simulating 10 groups for integration 10.
# 2021-01-06 16:36:07,605 - INFO - Adding the DARK calibration from ./CDP/MIRI_FM_MIRIFULONG_FAST_34_DARK_06.01.00.fits
# 2021-01-06 16:36:08,683 - INFO - Correcting nonlinearity from MIRI_FM_MIRIFULONG_34MEDIUM_LINEARITY_06.02.00.fits
# 2021-01-06 16:36:12,121 - INFO - Output subarray undefined or FULL. SUBSTRT=(1,1), SUBSIZE=(1032,1024)
# 2021-01-06 16:36:12,122 - INFO - WCS keywords defined as CRPIX1=0, CRPIX2=0
# 2021-01-06 16:36:14,656 - INFO - Exposure time 277.50s (duration 278.56s)
# 2021-01-06 16:36:21,383 - INFO - Wrote detector image: 20210106_161215_mirisim/det_images/det_image_seq1_MIRIFULONG_34MEDIUMexp2.fits
# 2021-01-06 16:36:21,385 - INFO - MIRI Simulation finished. Results have been saved to: 20210106_161215_mirisim

# %% [markdown]
# # 4) Examine some of the results
#
# Now that the MIRISim simulation has completed, lets examine the results.
#
#
# The first thing to note is that the outputs are placed in a date-labelled directory taking the form  <code> YYYYMMDD_hhmmss_mirisim</code>.  The name of the output directory is given in the last line of the MIRISim log above.  Because the output directory is date-labelled, we can quantify which was the most recent run of MIRISim, and find its output directory using <code>glob.glob</code>

# %%
outputdir = sorted(glob.glob('*_*_mirisim'),key=os.path.getmtime)[-1]    #[-1] takes the last entry found

outputDirContents = os.listdir(outputdir)

directories = [name for name in outputDirContents if os.path.isdir(os.path.join(outputdir,name))]
files = [name for name in outputDirContents if not os.path.isdir(os.path.join(outputdir,name))]

print('The subdirectories in the outputdirectory are:\n{}'.format(directories))
print('The files in the outputdirectory are:\n{}'.format(files))
# Out:
# The subdirectories in the outputdirectory are:
# ['det_images', 'skycubes', 'illum_models']
# The files in the outputdirectory are:
# ['simulator.ini', 'scene.ini', 'mrs_recommended_dither.dat', 'simulation.ini', 'mirisim.log']

# %% [markdown]
# The files contain the log which was also output to the terminal (<code> mirisim.log</code>) and copies of the .ini files used (or created from python inputs) to create the simulation. These versions of the .ini files can be used to re-create the run of the simulation
#
# The directories contain various outputs of MIRISim:
#
# * **<code> skycubes </code>** houses a 3D representation of the input scene to the MRS simulation (skycubes are not generated for imager or LRS simulations). This cube has not been processed by MIRISim, it is simply a gridded (spatially and spectrally) version of the input scene.
# * **<code> illum_models </code>** houses FITS images of the illuminations sent to the detector (sent to SCAsim - the simulator of the Sensor Chip Assembly).  This should have the same format as the detector image, but without all of the detector effects and noise. There are FITS files produced for each exposure and dither position
# * **<code> det_images </code>** houses FITS images of the final outputs of MIRISim. These detector images have all of the detector effects and noise incorporated. The number of detector images should be the same as the number of illumination models.
#
# The headers of the detector images are formatted for ingest into the JWST pipeline.
#
# Below is a small code snippet used to draw the images.  it needs to be run, but doesn't produce any output directly (it's called later to show the output images)

# %%
def show_outputs(MIRISim_outputdir,output_type):
    '''
    plot the specified channel of the MIRISim outputs
    :param MIRISim_outputdir:  
        name of the date-labelled dir. holding the MIRISIM outputs
    :param output_type: 
        type of output to process 
        (e.g. illum_models, det_images or skycubes)
    '''
    
    infits = glob.glob('{}/{}/*.fits'.format(MIRISim_outputdir,output_type))[0]
    
    hdulist = fits.open(infits)
    
    if output_type.lower() == 'skycubes': 
        hdu_index = 0
        datashape = hdulist[hdu_index].data.shape
        central_chan = datashape[0]/2
        plt.imshow(hdulist[hdu_index].data[central_chan,:,:],
           origin = 'lower', interpolation = 'nearest',cmap = cm.viridis)
        plt.title('channel {} of {}'.format(central_chan,infits.split('/')[-1]))
        plt.xlabel(hdulist[hdu_index].header['ctype1'])
        plt.ylabel(hdulist[hdu_index].header['ctype2'])
    else:
        hdu_index = 1
        if len(hdulist[hdu_index].data.shape) > 2:
            integ,frames,nx,ny = hdulist[hdu_index].data.shape
            image = hdulist[hdu_index].data[integ-1,frames-1,:,:]
        else:
            image = hdulist[hdu_index].data
            
        
        plt.imshow(image, origin = 'lower',cmap = cm.viridis,interpolation='nearest')
        plt.title('{}'.format(infits.split('/')[-1]))
        plt.xlabel('Along Slice Direction')
        plt.ylabel('Wavelength Direction')


    plt.colorbar()
    plt.savefig('MRS_{}.png'.format(output_type))

# %% [markdown]
# ### Viewing a slice of the skycube
#
# Below, we show an image of the central channel of one of the skycubes generated by MIRISim

# %%
#show_outputs(outputdir,'skycubes')
# Doesn't appear to be working.

# %% [markdown]
# ### Viewing an illumination model
#
# Below shows an example of an output illumination model

# %%
show_outputs(outputdir,'illum_models')

# %% [markdown]
# ### Viewing the final detector image
#
# The detector images are the final output of MIRISim, and have data structures and formatting consistent with what will come from MIRI itself. The data format is JWST pipeline ready.  Below an example image of the last frame of the last integration is shown. The units are <code>DN</code>.
#
# Additionally, below the FITS header information for the SCIENCE extension is listed.
#
# This is the "Level 1" data.

# %%
show_outputs(outputdir,'det_images')

infits = glob.glob('{}/det_images/*.fits'.format(outputdir))[0]
hdulist = fits.open(infits)
hdulist[1].header
# Out:
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    4 / number of array dimensions
# NAXIS1  =                 1032
# NAXIS2  =                 1024
# NAXIS3  =                   10
# NAXIS4  =                   10
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# EXTNAME = 'SCI     '           / extension name
#
#         Information about the coordinates in the file
#
# RADESYS = 'ICRS    '           / Name of the coordinate reference frame
#
#         Information about the data array
#
# BUNIT   = 'DN      '           / Units of the data array
#
#         Spacecraft pointing information
#
# RA_V1   =   0.1400128205112198 / [deg] RA of telescope V1 axis
# DEC_V1  =  0.08862257555178377 / [deg] Dec of telescope V1 axis
# PA_V3   =                 -0.0 / [deg] Position angle of telescope V3 axis
#
#         WCS parameters
#
# WCSAXES =                    3 / number of World Coordinate System axes
# CRPIX1  =                    0 / axis 1 coordinate of the reference pixel
# CRPIX2  =                    0 / axis 2 coordinate of the reference pixel
# CRPIX3  =                    0 / axis 3 coordinate of the reference pixel
# CRVAL1  =                  0.0 / first axis value at the reference pixel
# CRVAL2  =                  0.0 / second axis value at the reference pixel
# CRVAL3  =                  0.0 / third axis value at the reference pixel
# CTYPE1  = '' / first axis coordinate type
# CTYPE2  = '' / second axis coordinate type
# CTYPE3  = '' / third axis coordinate type
# CUNIT1  = '' / first axis units
# CUNIT2  = '' / second axis units
# CUNIT3  = '' / third axis units
# CDELT1  =                  1.0 / first axis increment per pixel
# CDELT2  =                  1.0 / second axis increment per pixel
# CDELT3  =                  1.0 / third axis increment per pixel
# V2_REF  =   -503.6544721447135 / [arcsec] Telescope v2 coordinate of the referen
# V3_REF  =    -318.742450697324 / [arcsec] Telescope v3 coordinate of the referen
# VPARITY =                   -1 / Relative sense of rotation between Ideal xy and
# V3I_YANG=                  0.0 / [deg] Angle from V3 axis to Ideal y axis
# RA_REF  = 0.000108800471021576 / [deg] Right ascension of the reference point
# DEC_REF = 8.30059136382191E-05 / [deg] Declination of the reference point
# ROLL_REF=                 -0.0 / [deg] V3 roll angle at the ref point (N over E)
# EXTVER  =                    1 / extension value

# %% [markdown]
# ### Next Steps
# * Run through MRS pipeline to test output products.
# * Patrick Kavanagh has provided some excellent notebooks at, https://github.com/PaddyKavanagh
# * For this dataset, Alistair adapted build7.2.1/MRS_pipeline.ipynb which runs all pipeline steps up to cube building and spectrum extraction.
