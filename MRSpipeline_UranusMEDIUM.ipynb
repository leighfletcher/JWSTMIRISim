# %% [markdown]
# **MIRI/MRS Pipeline Script applied to Uranus Cubes**
#
# Based heavily on notebooks by Patrick Kavanagh (DIAS, Ireland): https://github.com/PaddyKavanagh/build7.2.1_notebooks/blob/master/MRS_pipeline.ipynb
#
# * Installed from instructions on https://github.com/spacetelescope/jwst
# * `conda create -n jwst_test python`
# * `conda activate jwst_test`
# * `pip install jwst`
# * <code>export CRDS_PATH=$HOME/crds_cache</code>
# * <code>export CRDS_SERVER_URL=https://jwst-crds.stsci.edu</code>
# * Execution of the level 2A, 2B, and 3 pipelines for MRS data in Python.
# * `source activate jwst_test` before opening this notebook.
#
# The steps applied are:
# * Ramps to slopes pipeline (Detector1Pipeline)
# * CALSPEC2 steps and spectral extraction from each dither (Spec2Pipeline)
# * Combination of dithers and spectral extraction (Spec3Pipeline)
# * Manual conversion of extracted spectra to Jy

# %%
# Imports

import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# set the CRDS_CONTEXT for the correct build (here 0.18.1)
os.environ["CRDS_CONTEXT"] = "jwst_0664.pmap"
os.environ["CRDS_PATH"] = "/Users/lnf2/crds_cache"


# %matplotlib inline
# %matplotlib notebook # if you want interactive plots
# Out:
# 2021-03-04 14:45:41,464 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# **Set input, output location and source type**
#
# Since we know the simulation is of a point source, we can set the source type metadata to 'POINT' at this stage as that information is used later in spectral extraction. Otherwise, the pipeline will set the default source type for MRS which is 'EXTENDED'

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'testdir'

input_dir = 'MIRIUranus_MEDIUM/det_images'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the source type as 'POINT'
for f in input_files:
    with datamodels.MIRIRampModel(f) as dm:
        dm.meta.target.source_type = 'EXTENDED'
        dm.save(os.path.join(input_dir, dm.meta.filename))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)
# Out:
# 2021-03-04 14:45:47,335 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:45:48,295 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# Print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:

    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band))
        print("\n\n")

    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print("ID\t Detector\t nInts\t nGrps\t rdPatt\t chan.\t band")
        print("--------------------------------------------------------------------------------------------------")
        print("MIRISim\t %s\t %d\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,channel,band))
        print("\n\n")

    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 nInts	 nGrps	 rdPatt	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFULONG	 3	 10	 FAST	 34	 MEDIUM
#
#
#
# Filename: MIRIUranus_MEDIUM/det_images/det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     110   ()
#   1  SCI           1 ImageHDU        49   (1032, 1024, 10, 3)   float32
#   2  PIXELDQ       1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   3  GROUPDQ       1 ImageHDU        11   (1032, 1024, 10, 3)   uint8
#   4  ERR           1 ImageHDU        11   (1032, 1024, 10, 3)   float32
#   5  REFOUT        1 ImageHDU        11   (258, 1024, 10, 3)   float32
#   6  ASDF          1 BinTableHDU     11   1R x 1C   [7555B]

# %% [markdown]
# Show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs = axs.ravel()

i = 0
for f in input_files:
    # open the input image as a jwst data model
    with datamodels.MIRIRampModel(f) as in_dm:

        dith_num = i+1
        axs[i].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[i].annotate('Dither %d' % dith_num, xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[i].set_facecolor('black')
        i += 1

plt.tight_layout()
plt.show()
# Out:
# 2021-03-04 14:46:27,661 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:27,878 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# ## Level 2A pipeline (ramps-to-slopes)
# Import the level 2A pipeline class and print description.
# The output level 2A files will be saved in the output_dir as '*_rate.fits'

# %%
#LEVEL 2A PIPELINE

from jwst.pipeline import Detector1Pipeline
print(Detector1Pipeline.__doc__)

for f in input_files:
    Detector1Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir,
                           steps={'ipc': {'skip': True},
                                  'dark_current': {'skip': True},
                                  'refpix': {'skip': True}})
# Out:
# 2021-03-04 14:46:37,880 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#
# 2021-03-04 14:46:37,921 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#     Detector1Pipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     ramp_fit, and gain_scale.
# 2021-03-04 14:46:38,141 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,155 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,171 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,186 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,202 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,219 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,235 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,252 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,267 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,281 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,296 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,312 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,326 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,340 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,355 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,369 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,394 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2021-03-04 14:46:38,396 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2021-03-04 14:46:38,398 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2021-03-04 14:46:38,399 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2021-03-04 14:46:38,402 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2021-03-04 14:46:38,403 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2021-03-04 14:46:38,405 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2021-03-04 14:46:38,406 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2021-03-04 14:46:38,408 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2021-03-04 14:46:38,409 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2021-03-04 14:46:38,411 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2021-03-04 14:46:38,413 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2021-03-04 14:46:38,416 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2021-03-04 14:46:38,418 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2021-03-04 14:46:38,420 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2021-03-04 14:46:38,421 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2021-03-04 14:46:38,423 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2021-03-04 14:46:38,747 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('MIRIUranus_MEDIUM/det_images/det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits',).
# 2021-03-04 14:46:38,756 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': False, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_ou ...
# 2021-03-04 14:46:38,769 - stpipe.Detector1Pipeline - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),
#
# 2021-03-04 14:46:38,887 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFULONG_34MEDIUMexp1.fits' reftypes = ['gain', 'linearity', 'mask', 'persat', 'readnoise', 'reset', 'rscd', 'saturation', 'superbias', 'trapdensity', 'trappars']
# 2021-03-04 14:46:38,894 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_gain_0006.fits'.
# 2021-03-04 14:46:38,895 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_linearity_0027.fits'.
# 2021-03-04 14:46:38,901 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_mask_0021.fits'.
# 2021-03-04 14:46:38,902 - stpipe.Detector1Pipeline - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2021-03-04 14:46:38,903 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_readnoise_0075.fits'.
# 2021-03-04 14:46:38,904 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_reset_0034.fits'.
# 2021-03-04 14:46:38,905 - stpipe.Detector1Pipeline - INFO - Prefetch for RSCD reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_rscd_0011.fits'.
# 2021-03-04 14:46:38,906 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_saturation_0021.fits'.
# 2021-03-04 14:46:38,906 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is 'N/A'.
# 2021-03-04 14:46:38,907 - stpipe.Detector1Pipeline - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 
- stpipe.Detector1Pipeline.jump - INFO - Working on integration 1:
# 2021-03-04 14:47:30,722 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 9806 pixels with at least one CR
# 2021-03-04 14:47:31,110 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 2:
# 2021-03-04 14:47:31,417 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 13771 pixels with at least one CR
# 2021-03-04 14:47:32,024 - stpipe.Detector1Pipeline.jump - INFO - Working on integration 3:
# 2021-03-04 14:47:32,269 - stpipe.Detector1Pipeline.jump - INFO - From highest outlier Two-point found 13718 pixels with at least one CR
# 2021-03-04 14:47:32,834 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 3.21802 sec
# 2021-03-04 14:47:32,836 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 3.392194
# 2021-03-04 14:47:32,840 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2021-03-04 14:47:33,007 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(3, 10, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12MEDIUMexp1.fits>,).
# 2021-03-04 14:47:33,009 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images', 'int_name': '', 'save_opt': False, 'opt_name': '', 'maximum_cores': 'none'}
# 2021-03-04 14:47:33,023 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_readnoise_0060.fits
# 2021-03-04 14:47:33,034 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_gain_0007.fits
# 2021-03-04 14:47:33,046 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2021-03-04 14:47:33,046 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2021-03-04 14:47:33,145 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of leading groups that are flagged as DO_NOT_USE: 1
# 2021-03-04 14:47:33,146 - stpipe.Detector1Pipeline.ramp_fit - INFO - MIRI dataset has all pixels in the final group flagged as DO_NOT_USE.
# 2021-03-04 14:48:10,951 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of groups per integration: 10
# 2021-03-04 14:48:10,952 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of integrations: 3
# 2021-03-04 14:48:11,047 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2021-03-04 14:48:11,220 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFUSHORT_12MEDIUMexp1.fits>,).
# 2021-03-04 14:48:11,221 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images'}
# 2021-03-04 14:48:11,243 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2021-03-04 14:48:11,244 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2021-03-04 14:48:11,246 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2021-03-04 14:48:11,379 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(3, 1024, 1032) from det_image_seq1_MIRIFUSHORT_12MEDIUMexp1.fits>,).
# 2021-03-04 14:48:11,380 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images'}
# 2021-03-04 14:48:11,403 - stpipe.Detector1Pipeline.gain_scale - INFO - GAINFACT not found in gain reference file
# 2021-03-04 14:48:11,404 - stpipe.Detector1Pipeline.gain_scale - INFO - Step will be skipped
# 2021-03-04 14:48:11,405 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2021-03-04 14:48:11,654 - stpipe.Detector1Pipeline - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_rateints.fits
# 2021-03-04 14:48:11,654 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2021-03-04 14:48:11,779 - stpipe.Detector1Pipeline - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_rate.fits
# 2021-03-04 14:48:11,780 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done

# %%
# Quick check of the pipeline steps applied in the output. We'll look at the first dither:
level2A_files = glob.glob(os.path.join(output_dir,'*_rate.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('dq_init: %s' % dm.meta.cal_step.dq_init)
    print('saturation: %s' % dm.meta.cal_step.saturation)
    print('ipc: %s' % dm.meta.cal_step.ipc)
    print('linearity: %s' % dm.meta.cal_step.linearity)
    print('rscd: %s' % dm.meta.cal_step.rscd)
    print('firstframe: %s' % dm.meta.cal_step.firstframe)
    print('lastframe: %s' % dm.meta.cal_step.lastframe)
    print('dark_current: %s' % dm.meta.cal_step.dark_sub)
    print('refpix: %s' % dm.meta.cal_step.refpix)
    print('jump: %s' % dm.meta.cal_step.jump)
    print('ramp_fit: %s' % dm.meta.cal_step.ramp_fit)
# Out:
# 2021-03-04 14:53:12,971 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# ipc: None
# linearity: COMPLETE
# rscd: COMPLETE
# firstframe: COMPLETE
# lastframe: COMPLETE
# dark_current: None
# refpix: None
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ## Level 2B pipeline
# import the level 2B pipeline class and print description.
# We pass the level 2A files. The output level 2B files will be saved in the output_dir as '*_cal.fits'.
# Note that since MIRISim does not add straylight, we can skip the straylight correction step.
#
# The level 2B pipeline for the MRS produces three files for each input:
# * _cal.fits - the calibrated level 2B file from each dither
# * _s3d.fits - the cube from each dither
# * _x1d.fits - the 1d spectrum from each dither

# %%
from jwst.pipeline import Spec2Pipeline
print(Spec2Pipeline.__doc__)

for f in level2A_files:
    Spec2Pipeline.call(f, output_use_model=True, save_results=True, output_dir=output_dir, 
                       steps={'straylight':{'skip':True}})
# Out:
# 2021-03-04 14:53:17,450 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, barshadow,  photom,
#     resample_spec, cube_build, and extract_1d.
# 2021-03-04 14:53:17,801 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2021-03-04 14:53:17,802 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2021-03-04 14:53:17,804 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2021-03-04 14:53:17,806 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2021-03-04 14:53:17,807 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2021-03-04 14:53:17,808 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2021-03-04 14:53:17,811 - stpipe.Spec2Pipeline.master_background - INFO - MasterBackgroundNrsSlitsStep instance created.
# 2021-03-04 14:53:17,813 - stpipe.Spec2Pipeline.master_background.flat_field - INFO - FlatFieldStep instance created.
# 2021-03-04 14:53:17,814 - stpipe.Spec2Pipeline.master_background.pathloss - INFO - PathLossStep instance created.
# 2021-03-04 14:53:17,816 - stpipe.Spec2Pipeline.master_background.barshadow - INFO - BarShadowStep instance created.
# 2021-03-04 14:53:17,818 - stpipe.Spec2Pipeline.master_background.photom - INFO - PhotomStep instance created.
# 2021-03-04 14:53:17,820 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2021-03-04 14:53:17,821 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2021-03-04 14:53:17,823 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2021-03-04 14:53:17,826 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2021-03-04 14:53:17,827 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2021-03-04 14:53:17,829 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2021-03-04 14:53:17,831 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2021-03-04 14:53:17,832 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2021-03-04 14:53:17,834 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2021-03-04 14:53:17,837 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2021-03-04 14:53:17,839 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2021-03-04 14:53:18,114 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_rate.fits',).
# 2021-03-04 14:53:18,132 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sigma': 3.0, 'maxiters': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.25, 'sip_degree': None, 'sip_max_inv_pix_error': 0.25, 'sip_inv_degree': None, 'sip_npoints': 32, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'grism_objects': None, 'mmag_extract': 99.0}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}}}, 'wavecorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, ' ...
# 2021-03-04 14:53:18,187 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_rate.fits' reftypes = ['apcorr', 'area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'drizpars', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'resol', 'sflat', 'specwcs', 'wavecorr', 'wavelengthrange', 'wfssbkg']
# 2021-03-04 14:53:18,195 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_distortion_0030.asdf  131.0 K bytes  (1 / 6 files) (0 / 144.0 M bytes)
# 2021-03-04 14:53:21,439 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_flat_0540.fits   21.2 M bytes  (2 / 6 files) (131.0 K / 144.0 M bytes)
# 2021-03-04 14:53:36,581 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_fringe_0034.fits   12.7 M bytes  (3 / 6 files) (21.3 M / 144.0 M bytes)
# 2021-03-04 14:53:45,406 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_photom_0064.fits   33.8 M bytes  (4 / 6 files) (34.0 M / 144.0 M bytes)
# 2021-03-04 14:53:59,118 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_regions_0026.asdf   76.1 M bytes  (5 / 6 files) (67.8 M / 144.0 M bytes)
# 2021-03-04 14:54:25,288 - CRDS - INFO -  Fetching  /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_specwcs_0021.asdf   42.1 K bytes  (6 / 6 files) (143.9 M / 144.0 M bytes)
# 2021-03-04 14:54:27,331 - stpipe.Spec2Pipeline - INFO - Prefetch for APCORR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf'.
# 2021-03-04 14:54:27,332 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2021-03-04 14:54:27,333 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2021-03-04 14:54:27,333 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2021-03-04 14:54:27,334 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2021-03-04 14:54:27,335 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits'.
# 2021-03-04 14:54:27,336 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2021-03-04 14:54:27,336 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2021-03-04 14:54:27,337 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_distortion_0030.asdf'.
# 2021-03-04 14:54:27,338 - stpipe.Spec2Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2021-03-04 14:54:27,338 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf'.
# 2021-03-04 14:54:27,339 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2021-03-04 14:54:27,340 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2021-03-04 14:54:27,340 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_flat_0540.fits'.
# 2021-03-04 14:54:27,341 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2021-03-04 14:54:27,341 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2021-03-04 14:54:27,342 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_fringe_0034.fits'.
# 2021-03-04 14:54:27,342 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2021-03-04 14:54:27,343 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2021-03-04 14:54:27,343 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2021-03-04 14:54:27,344 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2021-03-04 14:54:27,344 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2021-03-04 14:54:27,345 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 
- stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2021-03-04 15:05:21,330 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2021-03-04 15:05:21,536 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>, []).
# 2021-03-04 15:05:21,538 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'sigma': 3.0, 'maxiters': None}
# 2021-03-04 15:05:21,539 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2021-03-04 15:05:21,540 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2021-03-04 15:05:21,691 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>, []).
# 2021-03-04 15:05:21,692 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined'}
# 2021-03-04 15:05:21,693 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2021-03-04 15:05:21,694 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2021-03-04 15:05:21,843 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:21,844 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined'}
# 2021-03-04 15:05:21,845 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2021-03-04 15:05:21,846 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2021-03-04 15:05:22,000 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:22,002 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined'}
# 2021-03-04 15:05:22,014 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2021-03-04 15:05:22,015 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = None
# 2021-03-04 15:05:22,015 - stpipe.Spec2Pipeline.srctype - WARNING - SRCTYAPT keyword not found in input; using SRCTYPE instead
# 2021-03-04 15:05:22,016 - stpipe.Spec2Pipeline.srctype - INFO - Using input source type = EXTENDED
# 2021-03-04 15:05:22,018 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2021-03-04 15:05:22,172 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:22,173 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2021-03-04 15:05:22,244 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-03-04 15:05:23,097 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2021-03-04 15:05:23,273 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:23,275 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'method': 'ModShepard', 'roi': 50, 'power': 1.0}
# 2021-03-04 15:05:23,276 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2021-03-04 15:05:23,277 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2021-03-04 15:05:23,458 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:23,459 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined'}
# 2021-03-04 15:05:23,473 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_fringe_0044.fits
# 2021-03-04 15:05:23,520 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-03-04 15:05:23,520 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-03-04 15:05:23,521 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-03-04 15:05:24,368 - stpipe.Spec2Pipeline.fringe - INFO - DQ values in the reference file NOT used to update the output DQ.
# 2021-03-04 15:05:24,370 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2021-03-04 15:05:24,604 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:24,605 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'inverse': False, 'source_type': None}
# 2021-03-04 15:05:24,606 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2021-03-04 15:05:24,607 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2021-03-04 15:05:24,778 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:24,780 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'inverse': False, 'source_type': None}
# 2021-03-04 15:05:24,781 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2021-03-04 15:05:24,782 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2021-03-04 15:05:24,963 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<IFUImageModel(1024, 1032) from det_image_seq1_MIRIFULONG_34MEDIUMexp1_rate.fits>,).
# 2021-03-04 15:05:24,964 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'inverse': False, 'source_type': None}
# 2021-03-04 15:05:24,979 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_photom_0049.fits
# 2021-03-04 15:05:24,979 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2021-03-04 15:05:25,792 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2021-03-04 15:05:25,793 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFULONG
# 2021-03-04 15:05:25,794 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2021-03-04 15:05:25,795 - stpipe.Spec2Pipeline.photom - INFO -  band: MEDIUM
# 2021-03-04 15:05:25,858 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2021-03-04 15:05:25,870 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2021-03-04 15:05:26,129 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<IFUImageModel(1024, 1032) from MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits>,).
# 2021-03-04 15:05:26,132 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'multi', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}
# 2021-03-04 15:05:26,133 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2021-03-04 15:05:26,133 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2021-03-04 15:05:26,134 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: skyalign
# 2021-03-04 15:05:26,134 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: emsm
# 2021-03-04 15:05:26,135 - stpipe.Spec2Pipeline.cube_build - INFO - Power weighting distance: 2.0
# 2021-03-04 15:05:26,154 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes cover the MIRI Channels: ['3', '4']
# 2021-03-04 15:05:26,155 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes cover the MIRI subchannels: ['medium', 'medium']
# 2021-03-04 15:05:26,155 - stpipe.Spec2Pipeline.cube_build - INFO - Reading cube parameter file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits
# 2021-03-04 15:05:27,256 - stpipe.Spec2Pipeline.cube_build - INFO - Output IFUcube are constructed from all the data
# 2021-03-04 15:05:27,257 - stpipe.Spec2Pipeline.cube_build - INFO - Number of IFU cubes produced by this run = 1
# 2021-03-04 15:05:27,836 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2021-03-04 15:05:27,836 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-03-04 15:05:27,837 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    55  28.00  -0.00017839   0.20000000  -5.50000008   5.50000008
# 2021-03-04 15:05:27,837 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    45  23.00  -0.00011900   0.20000000  -4.50000007   4.50000007
# 2021-03-04 15:05:27,838 - stpipe.Spec2Pipeline.cube_build - INFO - Non-linear wavelength dimension; CDELT3 variable
# 2021-03-04 15:05:27,839 - stpipe.Spec2Pipeline.cube_build - INFO - axis#  Naxis  CRPIX    CRVAL     Min & Max (microns)
# 2021-03-04 15:05:27,839 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  2245   1.00  13.36956596  13.36956596  24.21399689
# 2021-03-04 15:05:27,840 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 3, medium
# 2021-03-04 15:05:27,841 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 4, medium
# 2021-03-04 15:05:27,841 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name: MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_s3d.fits
# 2021-03-04 15:05:28,190 - stpipe.Spec2Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 6757 with wavelength below 13.36698055267334
# 2021-03-04 15:09:30,700 - stpipe.Spec2Pipeline.cube_build - INFO - Time to match file to ifucube = 134.3 s
# 2021-03-04 15:09:31,011 - stpipe.Spec2Pipeline.cube_build - INFO - # of detector pixels not mapped to output plane: 5350 with wavelength above 24.22562026977539
# 2021-03-04 15:13:03,241 - stpipe.Spec2Pipeline.cube_build - INFO - Time to match file to ifucube = 131.5 s
# 2021-03-04 15:13:03,407 - stpipe.Spec2Pipeline.cube_build - INFO - Average # of holes/wavelength plane is < 1
# 2021-03-04 15:13:03,408 - stpipe.Spec2Pipeline.cube_build - INFO - Total # of holes for IFU cube is : 0
# 2021-03-04 15:13:03,412 - stpipe.Spec2Pipeline.cube_build - INFO - Time to find Cube Flux = 0.2 s
# 2021-03-04 15:13:03,661 - stpipe.Spec2Pipeline.cube_build - INFO - Update S_REGION to POLYGON ICRS  0.001321612 -0.001341224 0.001321612 0.001103221 359.998321612 0.001103221 359.998321612 -0.001341224
# 2021-03-04 15:13:03,691 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2021-03-04 15:13:04,054 - stpipe.Spec2Pipeline - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_s3d.fits
# 2021-03-04 15:13:04,213 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ModelContainer>,).
# 2021-03-04 15:13:04,215 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'smoothing_length': None, 'bkg_fit': 'poly', 'bkg_order': None, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'apply_apcorr': True}
# 2021-03-04 15:13:04,219 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-03-04 15:13:04,221 - stpipe.Spec2Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-03-04 15:13:07,423 - stpipe.Spec2Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-03-04 15:13:07,424 - stpipe.Spec2Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-03-04 15:13:07,425 - stpipe.Spec2Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-03-04 15:13:11,971 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_x1d.fits
# 2021-03-04 15:13:11,971 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2021-03-04 15:13:11,981 - stpipe.Spec2Pipeline - INFO - Finished processing product MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1
# 2021-03-04 15:13:11,982 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2021-03-04 15:13:12,834 - stpipe.Spec2Pipeline - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits
# 2021-03-04 15:13:12,835 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %%
# check of output

# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))
cube_files = glob.glob(os.path.join(output_dir,'*_s3d.fits'))

with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print('Check step information status:')
    print('assign_wcs: %s' % dm.meta.cal_step.assign_wcs)
    print('flat_field: %s' % dm.meta.cal_step.flat_field)
    print('srctype: %s' % dm.meta.cal_step.srctype)
    print('straylight: %s' % dm.meta.cal_step.straylight)
    print('fringe: %s' % dm.meta.cal_step.fringe)
    print('photom: %s' % dm.meta.cal_step.photom)
# Out:
# 2021-03-04 15:14:34,531 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Check step information status:
# assign_wcs: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# straylight: None
# fringe: COMPLETE
# photom: COMPLETE

# %% [markdown]
# Look at level 1B and calibrated level 2B image. We'll look at the first dither only.

# %%
# open the input image as a jwst data model
with datamodels.MIRIRampModel(input_files[0]) as in_dm:
    with datamodels.open(level2B_files[0]) as out_dm:
        
        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1.5e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_facecolor('black')
        axs[1].imshow(out_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=1000)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_facecolor('black')

        plt.tight_layout()
        plt.show()
# Out:
# 2021-03-04 15:14:42,978 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#
# 2021-03-04 15:14:42,982 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/jwst/lib/basic_utils.py:24: DeprecationWarning: "MIRIRampModel" is deprecated and will be removed. Use RampModel
#   warnings.warn(message.format(old_class=old_class.__name__, new_class=new_class.__name__),

# %% [markdown]
# Look at cube file. We'll look at the first dither only

# %%
# open the cube as a jwst data model
with datamodels.open(cube_files[0]) as cube_dm:
    
    # plot--------------------------------------
    # sum some of the the frames in each channel
    # Note the user may have to adjust the scaling
    # parameters
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e5,vmax=1e7))
    axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(np.sum(cube_dm.data[3000:3200], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1,vmax=1e6))
    axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    
    plt.tight_layout()
    plt.show()
    
# open the cube as a jwst data model
with datamodels.open(cube_files[1]) as cube_dm:
    
    # plot--------------------------------------
    # sum some of the the frames in each channel
    # Note the user may have to adjust the scaling
    # parameters
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e5,vmax=1e7))
    axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(np.sum(cube_dm.data[3000:3200], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1,vmax=1e6))
    axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')
    
    plt.tight_layout()
    plt.show()
# Out:
# 2021-03-04 15:14:53,915 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Level 3 pipeline
# We first create an association file in the output directory containing the list of level 2B files ("_cal.fits") produced by the level 2B pipeline.
#
# Create the level 3 association using the asn_from_list tool

# %%
call(["asn_from_list", "-o", "MRS_asn.json"] + level2B_files + ["--product-name", "dither"])


from jwst.pipeline import Spec3Pipeline
print(Spec3Pipeline.__doc__)

# read the association and run
dms = datamodels.open("MRS_asn.json")
Spec3Pipeline.call(dms, save_results=True, output_dir=output_dir,
                  steps={'cube_build': {'save_results': True, 'output_dir': output_dir},
                         'extract_1d': {'save_results': True, 'output_dir': output_dir},
                         'mrs_imatch': {'skip': True}})
# Out:
# 2021-03-04 15:15:06,201 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Spec3Pipeline: Processes JWST spectroscopic exposures from Level 2b to 3.
#
#     Included steps are:
#     assign moving target wcs (assign_mtwcs)
#     master background subtraction (master_background)
#     MIRI MRS background matching (mrs_imatch)
#     outlier detection (outlier_detection)
#     2-D spectroscopic resampling (resample_spec)
#     3-D spectroscopic resampling (cube_build)
#     1-D spectral extraction (extract_1d)
#     1-D spectral combination (combine_1d)
# 2021-03-04 15:15:22,144 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2021-03-04 15:15:22,146 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2021-03-04 15:15:22,148 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2021-03-04 15:15:22,149 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2021-03-04 15:15:22,152 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2021-03-04 15:15:22,153 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2021-03-04 15:15:22,156 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2021-03-04 15:15:22,157 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2021-03-04 15:15:22,159 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2021-03-04 15:15:22,425 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args (<ModelContainer>,).
# 2021-03-04 15:15:22,435 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '4.0 3.0', 'scale': '0.5 0.4', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'exptime', 'pixel_scale_ratio': 1.0, 'single': False, 'blendheaders': True, 'allowed_memory': None}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': 'poly', 'bkg_order': None, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'apply_apcorr': True}, 'combine_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'exptime_key': 'exposure_time'}}}
# 2021-03-04 15:15:22,439 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits' reftypes = ['apcorr', 'cubepar', 'drizpars', 'extract1d', 'resol']
# 2021-03-04 15:15:22,443 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf'.
# 2021-03-04 15:15:22,444 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits'.
# 2021-03-04 15:15:22,445 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2021-03-04 15:15:22,446 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf'.
# 2021-03-04 15:15:22,446 - stpipe.Spec3Pipeline - INFO - Prefetch for RESOL reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2021-03-04 15:15:22,447 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_cal.fits' reftypes = ['apcorr', 'cubepar', 'drizpars', 'extract1d', 'resol']
# 2021-03-04 15:15:22,452 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf'.
# 2021-03-04 15:15:22,454 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits'.
# 2021-03-04 15:15:22,455 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2021-03-04 15:15:22,456 - stpipe.Spec3Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf'.
# 2021-03-04 15:15:22,456 - stpipe.Spec3Pipeline - INFO - Prefetch for RESOL reference file is '/Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2021-03-04 15:15:22,457 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2021-03-04 15:15:22,678 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch running with args (<ModelContainer>,).
# 2021-03-04 15:15:22,679 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'mrs_imatch', 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}
# 2021-03-04 15:15:22,680 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step skipped.
# 2021-03-04 15:15:22,682 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch done
# 2021-03-04 15:15:22,857 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2021-03-04 15:15:22,860 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'exptime', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '4.0 3.0', 'scale': '0.5 0.4', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None}
# 2021-03-04 15:15:22,863 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing outlier detection on 2 inputs
# 2021-03-04 15:15:25,021 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing IFU outlier_detection for exptype MIR_MRS
# 2021-03-04 15:15:25,023 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2021-03-04 15:15:25,024 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2021-03-04 15:15:25,024 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2021-03-04 15:15:25,025 - stpipe.CubeBuildStep - INFO - Coordinate system to use: skyalign
# 2021-03-04 15:15:25,026 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: emsm
# 2021-03-04 15:15:25,026 - stpipe.CubeBuildStep - INFO - Power weighting distance: 2.0
# 2021-03-04 15:15:25,026 - stpipe.CubeBuildStep - INFO - Cube Type: Single cubes
# 2021-03-04 15:15:25,049 - stpipe.Spec3Pipeline.outlier_detection - INFO - The desired cubes cover the MIRI Channels: ['4']
# 2021-03-04 15:15:25,049 - stpipe.Spec3Pipeline.outlier_detection - INFO - The desired cubes cover the MIRI subchannels: ['medium']
# 2021-03-04 15:15:25,050 - stpipe.Spec3Pipeline.outlier_detection - INFO - Reading cube parameter file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits
# 2021-03-04 15:15:26,216 - stpipe.Spec3Pipeline.outlier_detection - INFO - Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2021-03-04 15:15:26,523 - stpipe.Spec3Pipeline.outlier_detection - INFO - Cube Geometry:
# 2021-03-04 15:15:26,523 - stpipe.Spec3Pipeline.outlier_detection - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-03-04 15:15:26,524 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 1    29  15.00   0.00005544   0.34999999  -5.07499991   5.07499991
# 2021-03-04 15:15:26,524 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 2    27  14.00  -0.00011900   0.34999999  -4.72499992   4.72499992
# 2021-03-04 15:15:26,525 - stpipe.Spec3Pipeline.outlier_detection - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2021-03-04 15:15:26,525 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 3   632   1.00  20.42300008   0.00600000  20.42000008  24.21200011
# 2021-03-04 15:15:26,525 - stpipe.Spec3Pipeline.outlier_detection - INFO - Cube covers channel, subchannel: 4, medium
# 2021-03-04 15:15:26,843 - stpipe.Spec3Pipeline.outlier_detection - INFO - # of detector pixels not mapped to output plane: 4506 with wavelength below 20.41700007626787
# 2021-03-04 15:15:26,843 - stpipe.Spec3Pipeline.outlier_detection - INFO - # of detector pixels not mapped to output plane: 6252 with wavelength above 24.21500010928139
# 2021-03-04 15:16:25,287 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 1
# 2021-03-04
- stpipe.Spec3Pipeline.outlier_detection - INFO - The desired cubes cover the MIRI Channels: ['3']
# 2021-03-04 15:19:45,130 - stpipe.Spec3Pipeline.outlier_detection - INFO - The desired cubes cover the MIRI subchannels: ['medium']
# 2021-03-04 15:19:45,130 - stpipe.Spec3Pipeline.outlier_detection - INFO - Reading cube parameter file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_cubepar_0003.fits
# 2021-03-04 15:19:46,212 - stpipe.Spec3Pipeline.outlier_detection - INFO - Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2021-03-04 15:19:46,528 - stpipe.Spec3Pipeline.outlier_detection - INFO - Cube Geometry:
# 2021-03-04 15:19:46,528 - stpipe.Spec3Pipeline.outlier_detection - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(arcsec)  Min & Max (xi, eta arcsec)
# 2021-03-04 15:19:46,529 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 1    37  19.00  -0.00012366   0.20000000  -3.70000006   3.70000006
# 2021-03-04 15:19:46,529 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 2    37  19.00  -0.00004586   0.20000000  -3.70000006   3.70000006
# 2021-03-04 15:19:46,530 - stpipe.Spec3Pipeline.outlier_detection - INFO - axis#  Naxis  CRPIX    CRVAL      CDELT(microns)  Min & Max (microns)
# 2021-03-04 15:19:46,530 - stpipe.Spec3Pipeline.outlier_detection - INFO - Axis 3   757   1.00  13.37149989   0.00300000  13.36999989  15.64099991
# 2021-03-04 15:19:46,531 - stpipe.Spec3Pipeline.outlier_detection - INFO - Cube covers channel, subchannel: 3, medium
# 2021-03-04 15:19:46,892 - stpipe.Spec3Pipeline.outlier_detection - INFO - # of detector pixels not mapped to output plane: 6977 with wavelength below 13.368499885546044
# 2021-03-04 15:19:46,893 - stpipe.Spec3Pipeline.outlier_detection - INFO - # of detector pixels not mapped to output plane: 11286 with wavelength above 15.642499905312434
# 2021-03-04 15:20:55,646 - stpipe.CubeBuildStep - INFO - Number of Single IFUCube models returned 1
# 2021-03-04 15:20:55,648 - stpipe.Spec3Pipeline.outlier_detection - INFO - Update S_REGION to POLYGON ICRS  0.000876341 -0.001045856 0.000876341 0.000954145 359.998876341 0.000954145 359.998876341 -0.001045856
# 2021-03-04 15:20:56,098 - stpipe.Spec3Pipeline.outlier_detection - INFO - Information on Blotting
# 2021-03-04 15:20:56,099 - stpipe.Spec3Pipeline.outlier_detection - INFO - Working with instrument MIRI
# 2021-03-04 15:20:56,100 - stpipe.Spec3Pipeline.outlier_detection - INFO - shape of sky cube 37.000000 37.000000 757.000000
# 2021-03-04 15:20:56,100 - stpipe.Spec3Pipeline.outlier_detection - INFO - Channel 3
# 2021-03-04 15:20:56,101 - stpipe.Spec3Pipeline.outlier_detection - INFO - Sub-channel medium
# 2021-03-04 15:20:56,102 - stpipe.Spec3Pipeline.outlier_detection - INFO - Number of input models 1
# 2021-03-04 15:20:57,786 - stpipe.Spec3Pipeline.outlier_detection - INFO - Blotting back to det_image_seq1_MIRIFULONG_34MEDIUMexp1_cal.fits
# 2021-03-04 15:21:32,224 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFULONG_34MEDIUMexp1_a3001_crf.fits
# 2021-03-04 15:21:33,379 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/det_image_seq1_MIRIFUSHORT_12MEDIUMexp1_a3001_crf.fits
# 2021-03-04 15:21:33,380 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2021-03-04 15:21:33,954 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<ModelContainer>,).
# 2021-03-04 15:21:33,957 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'MIRIUranus_MEDIUM/det_images_pipelined', 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'emsm', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'xdebug': None, 'ydebug': None, 'zdebug': None, 'skip_dqflagging': False}
# 2021-03-04 15:21:33,957 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 
- stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-03-04 15:26:03,529 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-03-04 15:26:07,041 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-03-04 15:26:07,042 - stpipe.Spec3Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-03-04 15:26:07,043 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-03-04 15:26:08,347 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_extract1d_0001.asdf
# 2021-03-04 15:26:08,349 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/lnf2/crds_cache/references/jwst/miri/jwst_miri_apcorr_0001.asdf
# 2021-03-04 15:26:11,733 - stpipe.Spec3Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_MRS
# 2021-03-04 15:26:11,734 - stpipe.Spec3Pipeline.extract_1d - INFO - Setting use_source_posn to False for source type EXTENDED
# 2021-03-04 15:26:11,735 - stpipe.Spec3Pipeline.extract_1d - INFO - Source type = EXTENDED
# 2021-03-04 15:26:12,806 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/dither_ch1-medium_x1d.fits
# 2021-03-04 15:26:12,885 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/dither_ch2-medium_x1d.fits
# 2021-03-04 15:26:12,972 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/dither_ch3-medium_x1d.fits
# 2021-03-04 15:26:13,058 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in MIRIUranus_MEDIUM/det_images_pipelined/dither_ch4-medium_x1d.fits
# 2021-03-04 15:26:13,058 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2021-03-04 15:26:13,059 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2021-03-04 15:26:13,059 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
cube_files = sorted(glob.glob(os.path.join(output_dir, 'dither*s3d.fits')))
ch1_cdm = datamodels.open(cube_files[0])
ch2_cdm = datamodels.open(cube_files[1])

fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(ch1_cdm.data[100:-100], axis=0), cmap='inferno', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1e7))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(ch2_cdm.data[100:-100], axis=0), cmap='inferno', interpolation='nearest', origin='lower', norm=LogNorm(vmin=1e4,vmax=1e8))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()
# Out:
# 2021-03-04 15:39:24,559 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
spec_files = sorted(glob.glob(os.path.join(output_dir, 'dither*1d.fits')))
ch1_sdm = datamodels.open(spec_files[0])
ch2_sdm = datamodels.open(spec_files[1])

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# plot the spectrum in the channel 2 wavelength range
spaxel_area = ch1_cdm.meta.wcsinfo.cdelt1 * ch1_cdm.meta.wcsinfo.cdelt2 * 3600**2
axs[0].plot(ch1_sdm.spec[0].spec_table['WAVELENGTH'], ch1_sdm.spec[0].spec_table['FLUX'] * spaxel_area, c='orange', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[0].set_ylabel(r'Flux (mJy)')
axs[0].set_xlabel(r'Wavelength ($\mu$m)')
#axs[0].set_xlim(4.9,30)
#axs[0].set_ylim(10,200)

spaxel_area = ch2_cdm.meta.wcsinfo.cdelt1 * ch2_cdm.meta.wcsinfo.cdelt2 * 3600**2
axs[1].plot(ch2_sdm.spec[0].spec_table['WAVELENGTH'], ch2_sdm.spec[0].spec_table['FLUX']  * spaxel_area, c='g', marker='.', markersize=0, linestyle='-', linewidth=2)
axs[1].set_xlabel(r'Wavelength ($\mu$m)')
#axs[1].set_xlim(7.5,8.7)

axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].grid()
axs[1].grid()

plt.tight_layout()
plt.show()
# Out:
# 2021-03-04 15:39:32,084 - stpipe - WARNING - /opt/anaconda3/envs/jwst_test/lib/python3.9/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
